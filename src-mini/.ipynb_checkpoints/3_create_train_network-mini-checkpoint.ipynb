# %%
import dynet as dynet
import random
import matplotlib
# matplotlib.use('agg')
import matplotlib.pyplot as plt
import numpy as np
import pickle
# %run utils.ipynb
import time
# %matplotlib inline

# %%
def train_network():
    t0 = time.time()

    we = 100
    pe = 50
    hidden = 200
    minibatch = 1000
    epochs = 20

    net_properties = NetProperties(we, pe, hidden, minibatch)
    vocab = Vocab("../data/mini/features/train.data")
    
    pickle.dump((vocab, net_properties), open("../data/mini/vocab_net.data", 'wb'))
    network = Network(vocab, net_properties)
    (loss_values, validation_accs, train_accs) = network.train("../data/mini/features/train.data", epochs, "../data/mini/features/validation.data")
    network.save("../data/mini/net.model")

    t1 = time.time()
    total = t1 - t0
    print("runtime: " + str(total))
    return (loss_values, validation_accs, train_accs)

# %%
(loss_values, validation_accs, train_accs) = train_network()
# Out:
# started epoch 1
# current minibatch loss 4.397110939025879 progress: 7.18 %
# current minibatch loss 4.327518463134766 progress: 14.35 %
# current minibatch loss 4.267446041107178 progress: 21.53 %
# current minibatch loss 4.1894025802612305 progress: 28.7 %
# current minibatch loss 4.129770755767822 progress: 35.88 %
# current minibatch loss 4.101385593414307 progress: 43.05 %
# current minibatch loss 4.054296970367432 progress: 50.23 %
# current minibatch loss 4.034719944000244 progress: 57.4 %
# current minibatch loss 3.9737753868103027 progress: 64.58 %
# current minibatch loss 3.8759779930114746 progress: 71.76 %
# current minibatch loss 3.8644559383392334 progress: 78.93 %
# current minibatch loss 3.7705211639404297 progress: 86.11 %
# current minibatch loss 3.752378225326538 progress: 93.28 %
# started epoch 2
# current minibatch loss 3.707369327545166 progress: 0.72 %
# current minibatch loss 3.6863317489624023 progress: 7.89 %
# current minibatch loss 3.665236711502075 progress: 15.07 %
# current minibatch loss 3.568256139755249 progress: 22.24 %
# current minibatch loss 3.518030881881714 progress: 29.42 %
# current minibatch loss 3.5392603874206543 progress: 36.6 %
# current minibatch loss 3.5020923614501953 progress: 43.77 %
# current minibatch loss 3.5082132816314697 progress: 50.95 %
# current minibatch loss 3.4524121284484863 progress: 58.12 %
# current minibatch loss 3.4780783653259277 progress: 65.3 %
# current minibatch loss 3.401236057281494 progress: 72.47 %
# current minibatch loss 3.4719202518463135 progress: 79.65 %
# current minibatch loss 3.368851900100708 progress: 86.82 %
# current minibatch loss 3.3491716384887695 progress: 94.0 %
# started epoch 3
# current minibatch loss 3.3437893390655518 progress: 1.44 %
# current minibatch loss 3.2433135509490967 progress: 8.61 %
# current minibatch loss 3.2876720428466797 progress: 15.79 %
# current minibatch loss 3.2409090995788574 progress: 22.96 %
# current minibatch loss 3.2412314414978027 progress: 30.14 %
# current minibatch loss 3.1665561199188232 progress: 37.31 %
# current minibatch loss 3.245695114135742 progress: 44.49 %
# current minibatch loss 3.0996382236480713 progress: 51.66 %
# current minibatch loss 3.0767788887023926 progress: 58.84 %
# current minibatch loss 3.065016269683838 progress: 66.02 %
# current minibatch loss 3.080850839614868 progress: 73.19 %
# current minibatch loss 3.13815975189209 progress: 80.37 %
# current minibatch loss 3.1222589015960693 progress: 87.54 %
# current minibatch loss 3.1340582370758057 progress: 94.72 %
# started epoch 4
# current minibatch loss 3.0172219276428223 progress: 2.15 %
# current minibatch loss 3.0691630840301514 progress: 9.33 %
# current minibatch loss 2.998656749725342 progress: 16.5 %
# current minibatch loss 3.0340192317962646 progress: 23.68 %
# current minibatch loss 2.891651153564453 progress: 30.86 %
# current minibatch loss 2.9053733348846436 progress: 38.03 %
# current minibatch loss 2.9248692989349365 progress: 45.21 %
# current minibatch loss 3.0184412002563477 progress: 52.38 %
# current minibatch loss 2.9024620056152344 progress: 59.56 %
# current minibatch loss 2.959001064300537 progress: 66.73 %
# current minibatch loss 2.8671987056732178 progress: 73.91 %
# current minibatch loss 2.9076576232910156 progress: 81.08 %
# current minibatch loss 2.810957670211792 progress: 88.26 %
# current minibatch loss 2.8218655586242676 progress: 95.44 %
# started epoch 5
# current minibatch loss 2.834817409515381 progress: 2.87 %
# current minibatch loss 2.786226272583008 progress: 10.05 %
# current minibatch loss 2.8022501468658447 progress: 17.22 %
# current minibatch loss 2.7690863609313965 progress: 24.4 %
# current minibatch loss 2.881748914718628 progress: 31.57 %
# current minibatch loss 2.7282001972198486 progress: 38.75 %
# current minibatch loss 2.7473442554473877 progress: 45.92 %
# current minibatch loss 2.753796100616455 progress: 53.1 %
# current minibatch loss 2.76416277885437 progress: 60.28 %
# current minibatch loss 2.6973705291748047 progress: 67.45 %
# current minibatch loss 2.747196912765503 progress: 74.63 %
# current minibatch loss 2.7602293491363525 progress: 81.8 %
# current minibatch loss 2.7237563133239746 progress: 88.98 %
# current minibatch loss 2.781599760055542 progress: 96.15 %
# started epoch 6
# current minibatch loss 2.6746973991394043 progress: 3.59 %
# current minibatch loss 2.6272335052490234 progress: 10.76 %
# current minibatch loss 2.667179822921753 progress: 17.94 %
# current minibatch loss 2.6899163722991943 progress: 25.11 %
# current minibatch loss 2.6637561321258545 progress: 32.29 %
# current minibatch loss 2.6062793731689453 progress: 39.47 %
# current minibatch loss 2.5901782512664795 progress: 46.64 %
# current minibatch loss 2.5903992652893066 progress: 53.82 %
# current minibatch loss 2.6246280670166016 progress: 60.99 %
# current minibatch loss 2.565845012664795 progress: 68.17 %
# current minibatch loss 2.550632953643799 progress: 75.34 %
# current minibatch loss 2.5636260509490967 progress: 82.52 %
# current minibatch loss 2.5259103775024414 progress: 89.7 %
# current minibatch loss 2.5465469360351562 progress: 96.87 %
# started epoch 7
# current minibatch loss 2.560361862182617 progress: 4.31 %
# current minibatch loss 2.5094494819641113 progress: 11.48 %
# current minibatch loss 2.456305742263794 progress: 18.66 %
# current minibatch loss 2.5575106143951416 progress: 25.83 %
# current minibatch loss 2.469496965408325 progress: 33.01 %
# current minibatch loss 2.509413242340088 progress: 40.18 %
# current minibatch loss 2.5525097846984863 progress: 47.36 %
# current minibatch loss 2.5291976928710938 progress: 54.53 %
# current minibatch loss 2.475466251373291 progress: 61.71 %
# current minibatch loss 2.52998685836792 progress: 68.89 %
# current minibatch loss 2.457599401473999 progress: 76.06 %
# current minibatch loss 2.449814558029175 progress: 83.24 %
# current minibatch loss 2.4896583557128906 progress: 90.41 %
# current minibatch loss 2.48207688331604 progress: 97.59 %
# started epoch 8
# current minibatch loss 2.36688232421875 progress: 5.02 %
# current minibatch loss 2.462278366088867 progress: 12.2 %
# current minibatch loss 2.3426642417907715 progress: 19.37 %
# current minibatch loss 2.3611080646514893 progress: 26.55 %
# current minibatch loss 2.3039374351501465 progress: 33.73 %
# current minibatch loss 2.342547655105591 progress: 40.9 %
# current minibatch loss 2.3155102729797363 progress: 48.08 %
# current minibatch loss 2.323132276535034 progress: 55.25 %
# current minibatch loss 2.4014482498168945 progress: 62.43 %
# current minibatch loss 2.425717830657959 progress: 69.6 %
# current minibatch loss 2.3862380981445312 progress: 76.78 %
# current minibatch loss 2.3540985584259033 progress: 83.95 %
# current minibatch loss 2.2797296047210693 progress: 91.13 %

# %%
plt.title("Loss over time")
plt.xlabel("Minibatch")
plt.ylabel("Loss")
plt.plot(*zip(*loss_values))

# %%
plt.title("Training/Validation Accuracy")
plt.xlabel("Minibatch")
plt.ylabel("Loss")
x, y = zip(*train_accs)
plt.plot(x, y, 'g')

x1, y1 = zip(*validation_accs)
plt.plot(x1, y1, 'r')
