# %%
import pickle
import dynet
import os
import numpy as np
# %run utils.ipynb

# %%
if __name__ == '__main__':
    (vocab, net_properties) = pickle.load(open('../data/vocab_net.data', 'rb'))
    network = Network(vocab, net_properties)
    network.load('../data/net.model')

    writer = open('../data/predictions.data', 'w')
    feature_list = pickle.load(open( "../data/test.data", "rb" ))

    correct = 0
    shiftstars, tps, fps, fns, shifts, tpss, fpss, fnss = 0, 0, 0, 0, 0, 0, 0, 0
    for feature_set in feature_list:
        pred = network.decode(feature_set[:-1])
        writer.write("ground truth: " + feature_set[-1] + ", prediction: " + pred + "\n\n")

        # count shift stars
        if pred == "shift star":
            if feature_set[-1] == "shift star":
                shiftstars += 1
                tpss += 1
            else:
                fpss += 1
        if feature_set[-1] == "shift star" and pred != "shift star":
            fnss += 1
            shiftstars += 1

        # count shifts
        if pred == "shift":
            if feature_set[-1] == "shift":
                shifts += 1
                tps += 1
            else:
                fps += 1
        if feature_set[-1] == "shift" and pred != "shift":
            fns += 1
            shifts += 1

        # total accuracy
        if pred == feature_set[-1]:
            correct += 1


    print("accuracy: " + str(float(correct)/len(feature_list)))

    print("----------------------------------------")

    precision_ss = tpss / (tpss + fpss)
    recall_ss = tpss / (tpss + fnss)
    print("star precision: " + str(precision_ss))
    print("star recall: " + str(recall_ss))
    print("total stars: " + str(shiftstars))
    print("star F1: " + str( 2*(precision_ss * recall_ss) / (precision_ss + recall_ss) ))

    print("----------------------------------------")

    precision_s = tps / (tps + fps)
    recall_s = tps / (tps + fns)
    print("shift precision: " + str(precision_s))
    print("shift recall: " + str(recall_s))
    print("total shifts: " + str(shifts))
    print("shift F1: " + str( 2*(precision_s * recall_s) / (precision_s + recall_s) ))

    writer.close()
# Out:
# accuracy: 0.836
# ----------------------------------------
# star precision: 0.8115942028985508
# star recall: 0.691358024691358
# total stars: 162
# star F1: 0.7466666666666666
# ----------------------------------------
# shift precision: 0.8550681683461766
# shift recall: 0.941579634464752
# total shifts: 3064
# shift F1: 0.8962410686548617

# %%
def remove_star(s):
    s = s.split()
    s = list(filter(lambda x: '*' not in x, s))
    return ' '.join(s)

def action(b, s, p):
    error = None

    if p.split()[0] == 'shift':
        if len(p.split()) > 1 and p.split()[1] == 'star':
            s.append(Node('*'))
            
        # normal shift
        try: s.append(b.pop(0))
        except: error = 'pop on empty buffer'

    elif p.split()[0] == 'unary':
        n = Node(clean(p.split()[1]))
        try:
            n.l = s.pop()
            s.append(n)
        except: error = 'unary on empty stack'

    else: # p.split()[0] == 'binary':
        n = Node(clean(p.split()[1]))
        try:
            n.r, n.l = s.pop(), s.pop()
            s.append(n)
        except: error = 'binary on insufficient stack'

    return b, s, error


if __name__ == '__main__':
    # load the network
    (vocab, net_properties) = pickle.load(open('../data/vocab_net.data', 'rb'))
    network = Network(vocab, net_properties)
    network.load('../data/net.model')

    # open treebank for testing
    treepath = "../treebank/treebank_3/parsed/mrg/wsj/23"

    # open file and save as one large string
    text = ""
    for filename in os.listdir(treepath):
        if filename.startswith('.'):
            continue
        with open(treepath + "/" + filename, 'r') as f:
            text += f.read().replace('\n', '')

    tree_string_list = []
    s = []
    start = 0
    for i in range(len(text)):
        if text[i] == "(":
            s.append("(")
        elif text[i] == ")":
            s.pop()
            if not s:
                tree_string_list.append(text[start : i + 1])
                start = i + 1

    # turn tree strings into tree_list
    tree_list = []
    for t in tree_string_list:
        tree_list.append((parse_tree(t[1:-1])))

    # use inorder traveral to generate sentences from trees
    sentences = []
    for t in tree_list:
        sentences.append(remove_star(inorder_sentence(t).lstrip()))

    # testing

    with open('../data/tree_pred.txt', 'w') as outfile:
        for s, t in zip(sentences, tree_list):
            s = [clean(x) for x in s.split()]
            
            #debug
            print(' '.join(s) + '\n') # print sentence
            outfile.write(' '.join(s) + '\n\n')

            # construct tree
            buff = list(map(Node, s))
            stack = []
            infinite_loop_count = 0 # terminate after 100 moves
            printed_from_error = False
            while buff or len(stack) > 1: # end when buff consumed & stack has tree
                
                
                # cast to string and predict
                stack, buff = list(map(tree_to_str, stack)), list(map(tree_to_str, buff))
                try: f = extract_features(datum(stack, buff, None))
                except: 
                    print('feature extraction error')
                    printed_from_error = True
                    break
                    

                pred = network.decode(rearrange([0] + f)[:-1])
                # outfile.write(str(f) + ' ' +  pred + '\n')

                # cast back to Node and complete action
                stack, buff = list(map(Node, stack)), list(map(Node, buff))
                buff, stack, error = action(buff, stack, pred)
                if error:
                    # outfile.write(error + '\n')
                    print('Error: ' + error)
                    print(stack_to_str(stack) + '\n')
                    printed_from_error = True
                    outfile.write('Error: '+ error + '\n')
                    break
#                 print(pred + '\n' + stack_to_str(stack) + '\n')
                outfile.write(pred + '\n' + stack_to_str(stack) + '\n\n')
                
                infinite_loop_count += 1
                if infinite_loop_count >= 150: 
                    print('infinite loop error')
                    print(stack_to_str(stack) + '\n')
                    printed_from_error = True
                    break
                
            if not printed_from_error: print(stack_to_str(stack) + '\n')
            print('GROUND TRUTH:\n' + tree_to_str(t) + '\n')
            print('-------------------end of sentence-----------------\n')
            outfile.write('GROUND TRUTH:\n' + tree_to_str(t) + '\n\n')
            outfile.write('-------------------end of sentence-----------------\n\n')
# Out:
# The economy 's temperature will be taken from several vantage points this week , with readings on trade , output , housing and inflation .
#
# [ (S (NP (DT The) (NP (NN economy) (POS 's))) (S (VBD temperature) (S (VP (MD will) (VP (VB be) (VP (NNS taken) (VP (PP (IN from) (NP (NP (JJ several) (NNS vantage)) (NNS points))) (VP (NP (DT this) (NN week)) (PP (, ,) (NP (PP (IN with) (NP (NNS readings) (PP (IN on) (NP (NN trade) (NP (, ,) (NN output)))))) (NP (, ,) (NP (NN housing) (NP (CC and) (NN inflation))))))))))) (. .))))]
#
# GROUND TRUTH:
#  (S (NP-SBJ-1 (NP (DT The) (NP_inner (NN economy) (POS 's))) (NN temperature)) (S_inner (VP (MD will) (VP (VB be) (VP (VBN taken) (VP_inner (NP (-NONE- *-1)) (VP_inner (PP-CLR (IN from) (NP (JJ several) (NP_inner (NN vantage) (NNS points)))) (VP_inner (NP-TMP (DT this) (NN week)) (VP_inner (, ,) (PP (IN with) (NP (NP (NNS readings)) (PP (IN on) (NP (NP (NN trade)) (NP_inner (, ,) (NP_inner (NP (NN output)) (NP_inner (, ,) (NP_inner (NP (NN housing)) (NP_inner (CC and) (NP (NN inflation)))))))))))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# The most troublesome report may be the August merchandise trade deficit due out tomorrow .
#
# [ (S (NP (DT The) (NP (JJ most) (NN troublesome))) (S (VP (VBD report) (VP (MD may) (VP (VB be) (NP (NP (DT the) (NP (JJ August) (NP (NN merchandise) (NP (NN trade) (NN deficit))))) (NP (JJ due) (NP (JJ out) (NN tomorrow))))))) (. .)))]
#
# GROUND TRUTH:
#  (S (NP-SBJ (DT The) (NP-SBJ_inner (ADJP (RBS most) (JJ troublesome)) (NN report))) (S_inner (VP (MD may) (VP (VB be) (NP-PRD (NP (DT the) (NP_inner (NNP August) (NP_inner (NN merchandise) (NP_inner (NN trade) (NN deficit))))) (ADJP (JJ due) (ADJP_inner (ADVP (IN out)) (NP-TMP (NN tomorrow))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# The trade gap is expected to widen to about $ 9 billion from July 's $ 7.6 billion , according to a survey by MMS International , a unit of McGraw-Hill Inc. , New York .
#
# [ (S (NP (DT The) (NP (NN trade) (NN gap))) (S (VP (VP (VBZ is) (VP (VBN expected) (VP (TO to) (VP (VB widen) (VP (NP (PP (TO to) (NP (RB about) (NP ($ $) (NP (CD 9) (NP (NONE billion))))))) (PP (IN from) (NP (NP (NNP July) (POS 's)) (NP ($ $) (NP (CD 7.6) (CD billion)))))))))) (VP (, ,) (NP (NP (NNP according)) (PP (TO to) (NP (NP (NP (DT a) (NN survey)) (PP (IN by) (NP (NNP MMS) (NNP International)))) (NP (, ,) (NP (NP (DT a) (NN unit)) (PP (IN of) (NP (NP (NNP McGraw-Hill) (NNP Inc.)) (NP (, ,) (NP (NNP New) (NNP York)))))))))))) (. .)))]
#
# GROUND TRUTH:
#  (S (NP-SBJ-1 (DT The) (NP-SBJ-1_inner (NN trade) (NN gap))) (S_inner (VP (VBZ is) (VP (VBN expected) (VP_inner (S (NP-SBJ (-NONE- *-1)) (VP (TO to) (VP (VB widen) (VP_inner (PP-DIR (TO to) (NP (QP (IN about) (QP_inner ($ $) (QP_inner (CD 9) (CD billion)))) (-NONE- *U*))) (PP-DIR (IN from) (NP (NP (NNP July) (POS 's)) (NP_inner (QP ($ $) (QP_inner (CD 7.6) (CD billion))) (-NONE- *U*)))))))) (VP_inner (, ,) (PP (VBG according) (PP (TO to) (NP (NP (DT a) (NN survey)) (PP (IN by) (NP (NP (NNP MMS) (NNP International)) (NP_inner (, ,) (NP (NP (DT a) (NN unit)) (PP (IN of) (NP (NP (NNP McGraw-Hill) (NNP Inc.)) (NP_inner (, ,) (NP (NNP New) (NNP York)))))))))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# Thursday 's report on the September consumer price index is expected to rise , although not as sharply as the 0.9 % gain reported Friday in the producer price index .
#
# [ (S (NP (NP (NNP Thursday) (POS 's)) (NN report)) (S (PP (IN on) (NP (NP (DT the) (NN September)) (NP (NN consumer) (NP (NN price) (NN index))))) (S (VP (VBZ is) (VP (VBN expected) (VP (TO to) (VP (VB rise) (NP (, ,) (NP (NN although) (NP (RB not) (NP (NP (ADVP (RB as)) (NNS sharply)) (PP (IN as) (NP (NP (DT the) (NP (NP (CD 0.9) (NN %)) (PRP gain))) (PP (IN reported) (NP (NP (NNP Friday)) (PP (IN in) (NP (DT the) (NP (NN producer) (NP (NN price) (NN index))))))))))))))))) (. .))))]
#
# GROUND TRUTH:
#  (S (NP-SBJ-1 (NP (NP (NNP Thursday) (POS 's)) (NN report)) (PP (IN on) (NP (DT the) (NP_inner (NNP September) (NP_inner (NN consumer) (NP_inner (NN price) (NN index))))))) (S_inner (VP (VBZ is) (VP (VBN expected) (S (NP-SBJ (-NONE- *-1)) (VP (TO to) (VP (VB rise) (VP_inner (, ,) (SBAR-ADV (IN although) (ADVP (ADVP (RB not) (ADVP_inner (RB as) (RB sharply))) (PP (IN as) (NP (NP (DT the) (NP_inner (ADJP (CD 0.9) (NN %)) (NN gain))) (VP (VBN reported) (VP_inner (NP (-NONE- *)) (VP_inner (NP-TMP (NNP Friday)) (PP-LOC (IN in) (NP (DT the) (NP_inner (NN producer) (NP_inner (NN price) (NN index)))))))))))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# That gain was being cited as a reason 0 the stock market was down early in Friday 's session , before it got started on its reckless 190-point plunge .
#
# infinite loop error
# [ (NP (DT That) (NN gain)),  (VP (VBD was) (VP (VBG being) (VP (NP (NONE cited)) (PP (PP (IN as) (NP (NP (DT a) (NN reason)) (NONE 0))) (NP (NP (DT the) (NN stock)) (NN market)))))),  (VBD was),  (ADJP (RB down) (RB early)),  (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (, (PP (IN in) (NP (NP (NNP Friday) (POS 's)) (NNP session))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))))]
#
# GROUND TRUTH:
#  (S (NP-SBJ-1 (DT That) (NN gain)) (S_inner (VP (VBD was) (VP (VBG being) (VP (VBD cited) (VP_inner (NP (-NONE- *-1)) (PP-CLR (IN as) (NP (NP (DT a) (NN reason)) (SBAR (WHADVP-3 (-NONE- 0)) (S (NP-SBJ (DT the) (NP-SBJ_inner (NN stock) (NN market))) (VP (VBD was) (VP_inner (ADVP-PRD (IN down)) (VP_inner (ADVP-TMP (RB early) (PP (IN in) (NP (NP (NNP Friday) (POS 's)) (NN session)))) (VP_inner (, ,) (VP_inner (SBAR-TMP (IN before) (S (NP-SBJ-2 (PRP it)) (VP (VBD got) (S (NP-SBJ (-NONE- *-2)) (VP (VBN started) (VP_inner (NP (-NONE- *-2)) (PP-CLR (IN on) (NP (PRP$ its) (NP_inner (JJ reckless) (NP_inner (JJ 190-point) (NN plunge))))))))))) (ADVP-PRP (-NONE- *T*-3))))))))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# Economists are divided as to how much manufacturing strength they expect to see in September reports on industrial production and capacity utilization , also due tomorrow .
#
# Error: binary on insufficient stack
# []
#
# GROUND TRUTH:
#  (S (NP-SBJ-1 (NNS Economists)) (S_inner (VP (VBP are) (VP (VBN divided) (VP_inner (NP (-NONE- *-1)) (PP (IN as) (PP (TO to) (SBAR (WHNP-3 (WHADVP (WRB how) (JJ much)) (WHNP-3_inner (VBG manufacturing) (NN strength))) (S (NP-SBJ-2 (PRP they)) (VP (VBP expect) (S (NP-SBJ (-NONE- *-2)) (VP (TO to) (VP (VB see) (VP_inner (NP (-NONE- *T*-3)) (PP-LOC (IN in) (NP (NP (NP (NNP September) (NNS reports)) (PP (IN on) (NP (NP (JJ industrial) (NN production)) (NP_inner (CC and) (NP (NN capacity) (NN utilization)))))) (NP_inner (, ,) (ADJP (ADVP (RB also)) (ADJP_inner (JJ due) (NP-TMP (NN tomorrow))))))))))))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# Meanwhile , September housing starts , due Wednesday , are thought to have inched upward .
#
# [ (S (NP (RB Meanwhile) (NP (, ,) (NP (NNP September) (NP (NP (NONE housing)) (NP (VB starts) (NP (, ,) (NP (JJ due) (NN Wednesday)))))))) (S (, ,) (S (VP (VBP are) (S (NP (NNS thought)) (VP (TO to) (VP (VB have) (NP (JJ inched) (NN upward)))))) (. .))))]
#
# GROUND TRUTH:
#  (S (ADVP (RB Meanwhile)) (S_inner (, ,) (S_inner (NP-SBJ (NP (NNP September) (NP_inner (NN housing) (NNS starts))) (NP-SBJ_inner (, ,) (NP-SBJ_inner (ADJP (JJ due) (NP (NNP Wednesday))) (, ,)))) (S_inner (VP (VBP are) (VP (VBN thought) (S (NP-SBJ (-NONE- *)) (VP (TO to) (VP (VB have) (VP (VBN inched) (ADVP (RB upward)))))))) (. .)))))
#
# -------------------end of sentence-----------------
#
# `` There 's a possibility of a surprise '' in the trade report , said 0 Michael Englund , director of research at MMS .
#
# [ (S (`` ``) (S (NP (NP (NP (NNP There) (POS 's)) (NP (DT a) (NN possibility))) (PP (IN of) (NP (NP (DT a) (NP (NN surprise) (NN ''))) (PP (IN in) (NP (DT the) (NP (NN trade) (NN report))))))) (S (, ,) (S (VBD said) (S (NONE 0) (S (NP (NP (NNP Michael) (NNP Englund)) (NP (, ,) (NP (NN director) (PP (IN of) (NP (NN research) (NP (IN at) (NN MMS))))))) (. .)))))))]
#
# GROUND TRUTH:
#  (SINV (S-TPC-1 (`` ``) (S-TPC-1_inner (NP-SBJ (EX There)) (VP (VBZ 's) (NP-PRD (NP (DT a) (NN possibility)) (PP (IN of) (NP (NP (DT a) (NN surprise)) (NP_inner ('' '') (PP-LOC (IN in) (NP (DT the) (NP_inner (NN trade) (NN report))))))))))) (SINV_inner (, ,) (SINV_inner (VP (VBD said) (SBAR (-NONE- 0) (S (-NONE- *T*-1)))) (SINV_inner (NP-SBJ (NP (NNP Michael) (NNP Englund)) (NP-SBJ_inner (, ,) (NP (NP (NN director)) (NP_inner (PP (IN of) (NP (NN research))) (PP (IN at) (NP (NNP MMS))))))) (. .)))))
#
# -------------------end of sentence-----------------
#
# A widening of the deficit , if it were combined with a stubbornly strong dollar , would exacerbate trade problems -- but the dollar weakened Friday as stocks plummeted .
#
# [ (S (NP (NP (DT A) (NN widening)) (PP (IN of) (NP (DT the) (NN deficit)))) (S (VP (, ,) (VP (SBAR (IN if) (S (NP (NP (PRP it)) (NP (VBD were) (NP (JJ combined) (NP (IN with) (NP (NP (DT a) (NP (NN stubbornly) (NP (JJ strong) (NN dollar)))) (, ,)))))) (VP (MD would) (VP (VB exacerbate) (NP (JJ trade) (NNS problems)))))) (VP (, --) (VP (CC but) (VP (NP (DT the) (NN dollar)) (VP (PP (IN weakened) (NP (NNP Friday) (NP (NNP as) (NNS stocks)))) (ADVP (RB plummeted)))))))) (. .)))]
#
# GROUND TRUTH:
#  (S (S (NP-SBJ (NP (DT A) (NN widening)) (PP (IN of) (NP (DT the) (NN deficit)))) (S_inner (, ,) (S_inner (SBAR-ADV (IN if) (S (NP-SBJ-1 (PRP it)) (VP (VBD were) (VP (VBN combined) (VP_inner (NP (-NONE- *-1)) (PP-CLR (IN with) (NP (DT a) (NP_inner (ADJP (RB stubbornly) (JJ strong)) (NN dollar))))))))) (S_inner (, ,) (S_inner (VP (MD would) (VP (VB exacerbate) (NP (NN trade) (NNS problems)))) (: --)))))) (S_inner (CC but) (S_inner (S (NP-SBJ (DT the) (NN dollar)) (VP (VBD weakened) (VP_inner (NP-TMP (NNP Friday)) (SBAR-TMP (IN as) (S (NP-SBJ (NNS stocks)) (VP (VBD plummeted))))))) (. .))))
#
# -------------------end of sentence-----------------
#
# In any event , Mr. Englund and many others say that the easy gains in narrowing the trade gap have already been made .
#
# Error: pop on empty buffer
# [ (IN In),  (NP (DT any) (NN event)),  (, ,),  (S (NP (NNP Mr.) (NNP Englund)) (S (NONE and) (S (NP (JJ many) (NNS others)) (VP (VBP say) (VP (PP (IN that) (NP (DT the) (NP (JJ easy) (NN gains)))) (VP (IN in) (VP (DT narrowing) (VP (NP (DT the) (NN trade)) (VP (IN gap) (VP (VBP have) (VP (RB already) (NP (NAC been) (NNS made))))))))))))),  (NP (NONE .))]
#
# GROUND TRUTH:
#  (S (PP (IN In) (NP (DT any) (NN event))) (S_inner (, ,) (S_inner (NP-SBJ (NP (NNP Mr.) (NNP Englund)) (NP-SBJ_inner (CC and) (NP (JJ many) (NNS others)))) (S_inner (VP (VBP say) (SBAR (IN that) (S (NP-SBJ-1 (NP (DT the) (NP_inner (JJ easy) (NNS gains))) (PP (IN in) (S-NOM (NP-SBJ (-NONE- *)) (VP (VBG narrowing) (NP (DT the) (NP_inner (NN trade) (NN gap))))))) (VP (VBP have) (VP_inner (ADVP-TMP (RB already)) (VP (VBN been) (VP (VBN made) (NP (-NONE- *-1))))))))) (. .)))))
#
# -------------------end of sentence-----------------
#
# `` Trade is definitely going to be more politically sensitive over the next six or seven months as improvement begins to slow , '' he said .
#
# [ (S (`` ``) (S (NNP Trade) (S (VP (VBZ is) (VP (NNP definitely) (VP (VBG going) (VP (TO to) (VP (VB be) (VP (NP (DT more) (NN politically)) (VP (NP (NONE sensitive)) (VP (PP (IN over) (NP (DT the) (NP (JJ next) (NN six)))) (VP (VP or) (VP (NP (CD seven) (NNS months)) (VP (VBP as) (NP (NN improvement) (NP (NN begins) (NP (TO to) (NP (VB slow) (NP (, ,) (NP (DT '') (NP (NNP he) (NN said))))))))))))))))))) (. .))))]
# GROUND TRUTH:
#  (S (`` ``) (S_inner (S-TPC-2 (NP-SBJ-3 (NN Trade)) (VP (VBZ is) (VP_inner (ADVP (RB definitely)) (VP (VBG going) (S (NP-SBJ (-NONE- *-3)) (VP (TO to) (VP (VB be) (VP_inner (ADJP-PRD (RBR more) (ADJP-PRD_inner (RB politically) (JJ sensitive))) (VP_inner (PP-TMP (IN over) (NP (DT the) (NP_inner (JJ next) (NP_inner (QP (CD six) (QP_inner (CC or) (CD seven))) (NNS months))))) (SBAR-TMP (IN as) (S (NP-SBJ-1 (NN improvement)) (VP (VBZ begins) (S (NP-SBJ (-NONE- *-1)) (VP (TO to) (VP (VB slow)))))))))))))))) (S_inner (, ,) (S_inner ('' '') (S_inner (NP-SBJ (PRP he)) (S_inner (VP (VBD said) (S (-NONE- *T*-2))) (. .)))))))
#
# -------------------end of sentence-----------------
#
# Exports are thought to have risen strongly in August , but probably not enough to offset the jump in imports , economists said .
#
# [ (S (VP (S (. Exports) (VP (VBP are) (VP (VBN thought) (VP (TO to) (VP (VB have) (VP (VB risen) (VP (RB strongly) (PP (IN in) (NP (NNP August)))))))))) (VP (, ,) (VP (CC but) (VP (VBP probably) (VP (RB not) (VP (RB enough) (VP (TO to) (VP (VB offset) (VP (NP (DT the) (NN jump)) (VP (PP (IN in) (NP (NP (NNS imports)) (NP (, ,) (NNS economists)))) (ADVP (RB said)))))))))))) (. .))]
#
# GROUND TRUTH:
#  (S (S-TPC-2 (NP-SBJ-1 (NNS Exports)) (VP (VBP are) (VP (VBN thought) (S (NP-SBJ (-NONE- *-1)) (VP (TO to) (VP (VB have) (VP (VBN risen) (ADVP (ADVP (RB strongly) (PP-TMP (IN in) (NP (NNP August)))) (ADVP_inner (, ,) (ADVP_inner (CC but) (ADVP (ADVP (RB probably)) (ADVP_inner (RB not) (ADVP_inner (RB enough) (S (NP-SBJ (-NONE- *)) (VP (TO to) (VP (VB offset) (NP (NP (DT the) (NN jump)) (PP (IN in) (NP (NNS imports)))))))))))))))))))) (S_inner (, ,) (S_inner (NP-SBJ (NNS economists)) (S_inner (VP (VBD said) (S (-NONE- *T*-2))) (. .)))))
#
# -------------------end of sentence-----------------
#
# Views on manufacturing strength are split between economists who read September 's low level of factory job growth as a sign of a slowdown and those who use the somewhat more comforting total employment figures in their calculations .
#
# [ (S (NNP Views) (S (PP (IN on) (NP (JJ manufacturing) (NNS strength))) (S (VP (VBP are) (VP (NP (DT split) (NP (IN between) (NNS economists))) (VP (WP who) (VP (NP (NP (NN read) (NP (NNP September) (NP (NN 's) (NP (NN low) (NN level))))) (PP (IN of) (PP (IN factory) (NP (NN job) (NN growth))))) (PP (IN as) (NP (NP (DT a) (NN sign)) (PP (IN of) (NP (NP (DT a) (NN slowdown)) (NP (CC and) (NP (NP (NP (DT those) (NN who)) (NP (VBG use) (NP (NP (DT the) (NP (JJ somewhat) (NN more))) (PP (IN comforting) (NP (JJ total) (NP (NN employment) (NNS figures))))))) (PP (IN in) (NP (PRP$ their) (NNS calculations))))))))))))) (. .))))]
#
# GROUND TRUTH:
#  (S (NP-SBJ (NP (NNS Views)) (PP (IN on) (NP (VBG manufacturing) (NN strength)))) (S_inner (VP (VBP are) (ADJP-PRD (VBN split) (PP (IN between) (NP (NP (NP (NNS economists)) (SBAR (WHNP-1 (WP who)) (S (NP-SBJ (-NONE- *T*-1)) (VP (VBP read) (VP_inner (NP (NP (NP (NNP September) (POS 's)) (NP_inner (JJ low) (NN level))) (PP (IN of) (NP (NN factory) (NP_inner (NN job) (NN growth))))) (PP (IN as) (NP (NP (DT a) (NN sign)) (PP (IN of) (NP (DT a) (NN slowdown)))))))))) (NP_inner (CC and) (NP (NP (DT those)) (SBAR (WHNP-2 (WP who)) (S (NP-SBJ (-NONE- *T*-2)) (VP (VBP use) (VP_inner (NP (DT the) (NP_inner (ADJP (RB somewhat) (ADJP_inner (JJR more) (VBG comforting))) (NP_inner (JJ total) (NP_inner (NN employment) (NNS figures))))) (PP (IN in) (NP (PRP$ their) (NNS calculations))))))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# The wide range of estimates for the industrial output number underscores the differences : The forecasts run from a drop of 0.5 % to an increase of 0.4 % , according to MMS .
#
# [ (S (NP (NP (DT The) (NP (JJ wide) (NN range))) (PP (IN of) (NP (NNP estimates) (PP (IN for) (NP (NP (DT the) (NP (JJ industrial) (NP (NN output) (NN number)))) (PP (IN underscores) (NP (DT the) (NN differences)))))))) (S (: :) (S (VP (NP (NP (DT The) (NP (NNP forecasts) (NN run))) (PP (IN from) (NP (NP (NP (DT a) (NN drop)) (PP (IN of) (NP (CD 0.5) (NN %)))) (PP (TO to) (NP (NP (DT an) (NN increase)) (PP (IN of) (NP (CD 0.4) (NN %)))))))) (VP (, ,) (NP (VBG according) (NP (TO to) (NN MMS))))) (. .))))]
#
# GROUND TRUTH:
#  (S (S (NP-SBJ (NP (DT The) (NP_inner (JJ wide) (NN range))) (PP (IN of) (NP (NP (NNS estimates)) (PP (IN for) (NP (DT the) (NP_inner (JJ industrial) (NP_inner (NN output) (NN number)))))))) (VP (VBZ underscores) (NP (DT the) (NNS differences)))) (S_inner (: :) (S_inner (S (NP-SBJ (DT The) (NNS forecasts)) (VP (VBD run) (VP_inner (PP-DIR (IN from) (NP (NP (DT a) (NN drop)) (PP (IN of) (NP (CD 0.5) (NN %))))) (VP_inner (PP-DIR (TO to) (NP (NP (DT an) (NN increase)) (PP (IN of) (NP (CD 0.4) (NN %))))) (VP_inner (, ,) (PP (VBG according) (PP (TO to) (NP (NNP MMS))))))))) (. .))))
#
# -------------------end of sentence-----------------
#
# A rebound in energy prices , which helped push up the producer price index , is expected to do the same in the consumer price report .
#
# [ (S (NP (NP (NP (DT A) (NN rebound)) (PP (IN in) (NP (NN energy) (NNS prices)))) (NP (, ,) (NP (NN which) (NP (NP (NN helped) (NN push)) (PP (IN up) (NP (DT the) (NP (NN producer) (NP (NN price) (NN index))))))))) (S (, ,) (S (VP (VBZ is) (VP (VBN expected) (VP (TO to) (VP (VB do) (VP (NP (DT the) (NN same)) (PP (IN in) (NP (DT the) (NP (NN consumer) (NP (NN price) (NN report)))))))))) (. .))))]
#
# GROUND TRUTH:
#  (S (NP-SBJ-2 (NP (DT A) (NN rebound)) (NP-SBJ-2_inner (PP (IN in) (NP (NN energy) (NNS prices))) (NP-SBJ-2_inner (, ,) (NP-SBJ-2_inner (SBAR (WHNP-1 (WDT which)) (S (NP-SBJ (-NONE- *T*-1)) (VP (VBD helped) (VP (VB push) (VP_inner (PRT (RP up)) (NP (DT the) (NP_inner (NN producer) (NP_inner (NN price) (NN index))))))))) (, ,))))) (S_inner (VP (VBZ is) (VP (VBN expected) (S (NP-SBJ (-NONE- *-2)) (VP (TO to) (VP (VB do) (VP_inner (NP (DT the) (JJ same)) (PP (IN in) (NP (DT the) (NP_inner (NN consumer) (NP_inner (NN price) (NN report))))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# The consensus view expects a 0.4 % increase in the September CPI after a flat reading in August .
#
# [ (S (NP (DT The) (NP (NN consensus) (NN view))) (S (VP (VBZ expects) (VP (NP (NP (DT a) (NP (NP (CD 0.4) (NN %)) (NN increase))) (PP (IN in) (NP (DT the) (NP (NNP September) (NN CPI))))) (PP (IN after) (NP (NP (DT a) (NP (JJ flat) (NN reading))) (PP (IN in) (NP (NNP August))))))) (. .)))]
#
# GROUND TRUTH:
#  (S (NP-SBJ (DT The) (NP-SBJ_inner (NN consensus) (NN view))) (S_inner (VP (VBZ expects) (VP_inner (NP (NP (DT a) (NP_inner (ADJP (CD 0.4) (NN %)) (NN increase))) (PP (IN in) (NP (DT the) (NP_inner (NNP September) (NNP CPI))))) (PP-TMP (IN after) (NP (NP (DT a) (NP_inner (JJ flat) (NN reading))) (PP-TMP (IN in) (NP (NNP August))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# Robert H. Chandross , an economist for Lloyd 's Bank in New York , is among those expecting a more moderate gain in the CPI than in prices at the producer level .
#
# Error: binary on insufficient stack
# []
#
# GROUND TRUTH:
#  (S (NP-SBJ (NP (NNP Robert) (NP_inner (NNP H.) (NNP Chandross))) (NP-SBJ_inner (, ,) (NP-SBJ_inner (NP (NP (DT an) (NN economist)) (PP (IN for) (NP (NP (NP (NNP Lloyd) (POS 's)) (NNP Bank)) (PP-LOC (IN in) (NP (NNP New) (NNP York)))))) (, ,)))) (S_inner (VP (VBZ is) (PP-PRD (IN among) (NP (NP (DT those)) (VP (VBG expecting) (NP (NP (DT a) (NP_inner (ADJP (RBR more) (JJ moderate)) (NN gain))) (NP_inner (PP-LOC (IN in) (NP (DT the) (NNP CPI))) (PP (IN than) (PP (IN in) (NP (NP (NNS prices)) (PP-LOC (IN at) (NP (DT the) (NP_inner (NN producer) (NN level))))))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# `` Auto prices had a big effect in the PPI , and at the CPI level they wo n't , '' he said .
#
# Error: binary on insufficient stack
# []
#
# GROUND TRUTH:
#  (S (`` ``) (S_inner (S-TPC-1 (S (NP-SBJ (NN Auto) (NNS prices)) (VP (VBD had) (VP_inner (NP (DT a) (NP_inner (JJ big) (NN effect))) (PP-LOC (IN in) (NP (DT the) (NNP PPI)))))) (S-TPC-1_inner (, ,) (S-TPC-1_inner (CC and) (S (PP-LOC (IN at) (NP (DT the) (NP_inner (NNP CPI) (NN level)))) (S_inner (NP-SBJ (PRP they)) (VP (MD wo) (VP_inner (RB n't) (VP (-NONE- *?*))))))))) (S_inner (, ,) (S_inner ('' '') (S_inner (NP-SBJ (PRP he)) (S_inner (VP (VBD said) (S (-NONE- *T*-1))) (. .)))))))
#
# -------------------end of sentence-----------------
#
# Food prices are expected to be unchanged , but energy costs jumped as much as 4 % , said 0 Gary Ciminero , economist at Fleet\/Norstar Financial Group .
# Error: binary on insufficient stack
# []
#
# GROUND TRUTH:
#  (SINV (S-TPC-1 (S (NP-SBJ-2 (NN Food) (NNS prices)) (VP (VBP are) (VP (VBN expected) (S (NP-SBJ (-NONE- *-2)) (VP (TO to) (VP (VB be) (ADJP-PRD (JJ unchanged)))))))) (S-TPC-1_inner (, ,) (S-TPC-1_inner (CC but) (S (NP-SBJ (NN energy) (NNS costs)) (VP (VBD jumped) (NP (NP (RB as) (NP_inner (RB much) (NP_inner (IN as) (CD 4)))) (NN %))))))) (SINV_inner (, ,) (SINV_inner (VP (VBD said) (SBAR (-NONE- 0) (S (-NONE- *T*-1)))) (SINV_inner (NP-SBJ (NP (NNP Gary) (NNP Ciminero)) (NP-SBJ_inner (, ,) (NP (NP (NN economist)) (PP-LOC (IN at) (NP (NNP Fleet\/Norstar) (NP_inner (NNP Financial) (NNP Group))))))) (. .)))))
#
# -------------------end of sentence-----------------
#
# He also says 0 he thinks 0 `` core inflation , '' which excludes the volatile food and energy prices , was strong last month .
#
# [ (S (NP (PRP He)) (S (RB also) (S (VBZ says) (S (NONE 0) (S (ADVP (S (NP (PRP he)) (VP (VBD thinks) (NP (NONE 0) (NP (`` ``) (NP (JJ core) (NN inflation))))))) (S (, ,) (S (NP (DT '') (NN which)) (S (CC excludes) (S (NP (NP (DT the) (NP (JJ volatile) (NN food))) (NP (CC and) (NP (NN energy) (NNS prices)))) (S (, ,) (S (VP (VP was) (NP (JJ strong) (NP (JJ last) (NN month)))) (. .))))))))))))]
#
# GROUND TRUTH:
#  (S (NP-SBJ (PRP He)) (S_inner (ADVP (RB also)) (S_inner (VP (VBZ says) (SBAR (-NONE- 0) (S (NP-SBJ (PRP he)) (VP (VBZ thinks) (SBAR (-NONE- 0) (S (NP-SBJ (`` ``) (NP-SBJ_inner (NP (NN core) (NN inflation)) (NP-SBJ_inner (, ,) (NP-SBJ_inner ('' '') (NP-SBJ_inner (SBAR (WHNP-1 (WDT which)) (S (NP-SBJ (-NONE- *T*-1)) (VP (VBZ excludes) (NP (DT the) (NP_inner (JJ volatile) (NP_inner (NN food) (NP_inner (CC and) (NP_inner (NN energy) (NNS prices))))))))) (, ,)))))) (VP (VBD was) (VP_inner (ADJP-PRD (JJ strong)) (NP-TMP (JJ last) (NN month)))))))))) (. .))))
#
# -------------------end of sentence-----------------
#
# He expects a gain of as much as 0.5 % in core inflation after a summer of far smaller increases .
#
# [ (S (NP (PRP He)) (S (VP (VBZ expects) (NP (NP (DT a) (NN gain)) (VP (IN of) (VP (RB as) (VP (RB much) (VP (PP (IN as) (NP (NP (CD 0.5) (NN %)) (PP (IN in) (NP (NN core) (NN inflation))))) (PP (IN after) (NP (NP (DT a) (NN summer)) (PP (IN of) (NP (RB far) (NP (NNP smaller) (NNS increases)))))))))))) (. .)))]
#
# GROUND TRUTH:
#  (S (NP-SBJ (PRP He)) (S_inner (VP (VBZ expects) (NP (NP (DT a) (NN gain)) (NP_inner (PP (IN of) (NP (QP (RB as) (QP_inner (JJ much) (QP_inner (IN as) (CD 0.5)))) (NN %))) (NP_inner (PP (IN in) (NP (NN core) (NN inflation))) (PP-TMP (IN after) (NP (NP (DT a) (NN summer)) (PP (IN of) (NP (ADJP (JJ far) (JJR smaller)) (NNS increases))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# Housing starts are expected to quicken a bit from August 's annual pace of 1,350,000 units .
#
# [ (S (NP (NNP Housing) (NNP starts)) (S (VP (VBP are) (VP (VBN expected) (VP (TO to) (VP (VB quicken) (VP (NP (DT a) (NN bit)) (PP (IN from) (NP (NP (NP (NNP August) (POS 's)) (NP (JJ annual) (NN pace))) (PP (IN of) (NP (NNP 1,350,000) (NNS units)))))))))) (. .)))]
#
# GROUND TRUTH:
#  (S (NP-SBJ (NN Housing) (NNS starts)) (S_inner (VP (VBP are) (VP (VBN expected) (S (NP-SBJ (-NONE- *)) (VP (TO to) (VP (VB quicken) (VP_inner (NP (DT a) (NN bit)) (PP (IN from) (NP (NP (NP (NNP August) (POS 's)) (NP_inner (JJ annual) (NN pace))) (PP (IN of) (NP (CD 1,350,000) (NNS units))))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# Economists say 0 an August rebound in permits for multifamily units signaled an increase in September starts , though activity remains fairly modest by historical standards .
#
# Error: binary on insufficient stack
# []
#
# GROUND TRUTH:
#  (S (NP-SBJ (NNS Economists)) (S_inner (VP (VBP say) (SBAR (-NONE- 0) (S (NP-SBJ (NP (DT an) (NP_inner (NNP August) (NN rebound))) (PP (IN in) (NP (NP (NNS permits)) (PP (IN for) (NP (RB multifamily) (NNS units)))))) (VP (VBD signaled) (VP_inner (NP (NP (DT an) (NN increase)) (PP (IN in) (NP (NNP September) (NNS starts)))) (VP_inner (, ,) (SBAR-ADV (IN though) (S (NP-SBJ (NN activity)) (S_inner (VP (VBZ remains) (ADJP-PRD (RB fairly) (JJ modest))) (PP (IN by) (NP (JJ historical) (NNS standards)))))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# Two-Way Street
#
# Error: pop on empty buffer
# [ (NNP Two-Way),  (NNP Street)]
#
# GROUND TRUTH:
#  (NP-HLN (NNP Two-Way) (NNP Street))
#
# -------------------end of sentence-----------------
#
# If the sixty-day plant-closing law 's fair , Why should we not then amend the writ To require that all employees give Similar notice before they quit ?
#
# Error: pop on empty buffer
# [ (PP (IN If) (NP (NP (DT the) (NP (JJ sixty-day) (NP (NN plant-closing) (NP (NN law) (POS 's))))) (NN fair))),  (, ,),  (S (NP (NNP Why)) (VP (MD should) (VP (NP (PRP we)) (VP (RB not) (VP (ADVP (RB then)) (SBAR (IN amend) (S (NP (DT the) (NP (JJ writ) (NN To))) (VP (VBZ require) (SBAR (IN that) (S (NP (DT all) (NNS employees)) (VP (VB give) (NP (NP (JJ Similar) (NNS notice)) (SBAR (IN before) (SBARQ (NP (PRP they)) (RB quit))))))))))))))),  (VBD ?)]
#
# GROUND TRUTH:
#  (SBARQ (SBAR-ADV (IN If) (S (NP-SBJ (DT the) (NP-SBJ_inner (JJ sixty-day) (NP-SBJ_inner (JJ plant-closing) (NN law)))) (VP (VBZ 's) (ADJP-PRD (JJ fair))))) (SBARQ_inner (, ,) (SBARQ_inner (SBARQ (WHADVP (WRB Why)) (SQ (MD should) (SQ_inner (NP-SBJ (PRP we)) (SQ_inner (RB not) (SQ_inner (ADVP (RB then)) (VP (VB amend) (VP_inner (NP (DT the) (NN writ)) (S-CLR (NP-SBJ (-NONE- *)) (VP (TO To) (VP (VB require) (SBAR (IN that) (S (NP-SBJ (DT all) (NNS employees)) (VP (VBP give) (VP_inner (NP (JJ Similar) (NN notice)) (SBAR-TMP (IN before) (S (NP-SBJ (PRP they)) (VP (VBP quit)))))))))))))))))) (. ?))))
#
# -------------------end of sentence-----------------
#
# -- Rollin S. Trexler .
#
# [ (S (VP --) (S (NP (DT Rollin) (NP (NNP S.) (NN Trexler))) (. .)))]
#
# GROUND TRUTH:
#  (NP-HLN (: --) (NP-HLN_inner (NNP Rollin) (NP-HLN_inner (NNP S.) (NP-HLN_inner (NNP Trexler) (. .)))))
#
# -------------------end of sentence-----------------
#
# Candid Comment
#
# Error: pop on empty buffer
# [ (JJ Candid),  (VBD Comment)]
#
# GROUND TRUTH:
#  (NP-HLN (NNP Candid) (NNP Comment))
#
# -------------------end of sentence-----------------
#
# When research projects are curtailed due to government funding cuts , are we `` caught with our grants down '' ?
#
# Error: binary on insufficient stack
# []
#
# GROUND TRUTH:
#  (SQ (SBAR-TMP (WHNP-4 (WRB When)) (S (NP-SBJ-1 (NN research) (NNS projects)) (VP (VBP are) (VP (VBN curtailed) (VP_inner (NP (-NONE- *-1)) (VP_inner (PP-PRP (JJ due) (PP-PRP_inner (TO to) (NP (NN government) (NP_inner (NN funding) (NNS cuts))))) (ADVP-TMP (-NONE- *T*-4)))))))) (SQ_inner (, ,) (SQ_inner (VBP are) (SQ_inner (NP-SBJ-3 (PRP we)) (SQ_inner (VP (`` ``) (VP_inner (VBN caught) (VP_inner (NP (-NONE- *-3)) (VP_inner (SBAR-CLR (IN with) (S (NP-SBJ (PRP$ our) (NNS grants)) (ADVP-PRD (IN down)))) ('' ''))))) (. ?))))))
#
# -------------------end of sentence-----------------
#
# -- C.E. Friedman .
#
# Error: binary on insufficient stack
# []
#
# GROUND TRUTH:
#  (NP-HLN (: --) (NP-HLN_inner (NNP C.E.) (NP-HLN_inner (NNP Friedman) (. .))))
#
# -------------------end of sentence-----------------
#
# Assuming 0 the stock market does n't crash again and completely discredit yuppies and trading rooms , American television audiences in a few months may be seeing Britain 's concept of both .
#
# Error: binary on insufficient stack
# []
#
# GROUND TRUTH:
#  (S (S-ADV (NP-SBJ (-NONE- *)) (VP (VBG Assuming) (SBAR (-NONE- 0) (S (NP-SBJ (DT the) (NP-SBJ_inner (NN stock) (NN market))) (VP (VBZ does) (VP_inner (RB n't) (VP (VP (VB crash) (ADVP-TMP (RB again))) (VP_inner (CC and) (VP (ADVP (RB completely)) (VP_inner (VB discredit) (NP (NP (NNS yuppies)) (NP_inner (CC and) (NP (NN trading) (NNS rooms)))))))))))))) (S_inner (, ,) (S_inner (NP-SBJ (JJ American) (NP-SBJ_inner (NN television) (NNS audiences))) (S_inner (PP-TMP (IN in) (NP (DT a) (NP_inner (JJ few) (NNS months)))) (S_inner (VP (MD may) (VP (VB be) (VP (VBG seeing) (NP (NP (NP (NNP Britain) (POS 's)) (NN concept)) (PP (IN of) (NP (DT both))))))) (. .))))))
#
# -------------------end of sentence-----------------
#
# `` Capital City '' is a weekly series that premiered here three weeks ago amid unprecedented hype by its producer , Thames Television .
#
# feature extraction error
# GROUND TRUTH:
#  (S (NP-TTL-SBJ (`` ``) (NP-TTL-SBJ_inner (NNP Capital) (NP-TTL-SBJ_inner (NNP City) ('' '')))) (S_inner (VP (VBZ is) (NP-PRD (NP (DT a) (NP_inner (JJ weekly) (NN series))) (SBAR (WHNP-1 (WDT that)) (S (NP-SBJ (-NONE- *T*-1)) (VP (VBD premiered) (VP_inner (NP-LOC-CLR (RB here)) (VP_inner (ADVP-TMP-CLR (NP (CD three) (NNS weeks)) (IN ago)) (PP-LOC (IN amid) (NP (NP (JJ unprecedented) (NN hype)) (PP (IN by) (NP (NP (PRP$ its) (NN producer)) (NP_inner (, ,) (NP (NNP Thames) (NNP Television)))))))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# The early episodes make you long for a rerun of the crash of 1987 .
#
# [ (S (NP (DT The) (NP (JJ early) (NN episodes))) (S (VP (VBD make) (NP (NP (DT you) (NN long)) (PP (IN for) (NP (NP (DT a) (NN rerun)) (PP (IN of) (NP (NP (DT the) (NN crash)) (PP (IN of) (NP (CD 1987))))))))) (. .)))]
#
# GROUND TRUTH:
#  (S (NP-SBJ (DT The) (NP-SBJ_inner (JJ early) (NNS episodes))) (S_inner (VP (VBP make) (S (NP-SBJ (PRP you)) (VP (JJ long) (PP-CLR (IN for) (NP (NP (DT a) (NN rerun)) (PP (IN of) (NP (NP (DT the) (NN crash)) (PP (IN of) (NP (CD 1987)))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# Let 's make that 1929 , just to be sure .
#
# Error: binary on insufficient stack
# []
#
# GROUND TRUTH:
#  (S (NP-SBJ (-NONE- *)) (S_inner (VP (VB Let) (S (NP-SBJ (PRP 's)) (VP (VB make) (VP_inner (S (NP-SBJ (DT that)) (NP-PRD (CD 1929))) (VP_inner (, ,) (S-PRP (ADVP (RB just)) (S-PRP_inner (NP-SBJ (-NONE- *)) (VP (TO to) (VP (VB be) (ADJP-PRD (JJ sure))))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# According to the program 's publicity prospectus , `` Capital City , '' set at Shane Longman , a fictional mid-sized securities firm with # 500 million capital , `` follows the fortunes of a close-knit team of young , high-flying dealers , hired for their particular blend of style , genius and energy .
# infinite loop error
# [ (NP (NN According)),  (NP (TO to) (NP (NP (DT the) (NP (NN program) (POS 's))) (NP (NN publicity) (NN prospectus)))),  (, ,),  (NP (ADJP (PP (VP ``) (NP (DT Capital) (NNP City))))),  (, ,),  (NP (DT '') (NN set)),  (IN at),  (NP (DT Shane) (NNS Longman)),  (, ,),  (NP (DT a) (NN fictional)),  (NONE mid-sized),  (NP (NN securities) (NP (NN firm) (PP (IN with) (NP (NNP #) (NP (CD 500) (NP (CD million) (NN capital))))))),  (, ,),  (VP (NP (DT ``) (NP (NN follows) (NP (DT the) (NN fortunes)))) (VP (IN of) (NP (NP (NP (DT a) (NN close-knit)) (NN team)) (PP (IN of) (NP (NP (NNP young)) (NP (, ,) (NP (JJ high-flying) (NNS dealers)))))))),  (, ,),  (NP (NNS hired)),  (IN for),  (NP (NP (PRP$ their) (NP (JJ particular) (NN blend))) (PP (IN of) (NP (NP (NN style)) (NP (, ,) (NP (NNS genius) (NP (CC and) (NN energy)))))))]
#
# GROUND TRUTH:
#  (S (PP (VBG According) (PP (TO to) (NP (NP (DT the) (NP_inner (NN program) (POS 's))) (NP_inner (NN publicity) (NN prospectus))))) (S_inner (, ,) (S_inner (NP-SBJ (`` ``) (NP-SBJ_inner (NP-TTL (NNP Capital) (NNP City)) (NP-SBJ_inner (, ,) (NP-SBJ_inner ('' '') (NP-SBJ_inner (VP (VBN set) (PP-LOC-CLR (IN at) (NP (NP (NNP Shane) (NNP Longman)) (NP_inner (, ,) (NP (NP (DT a) (NP_inner (JJ fictional) (NP_inner (JJ mid-sized) (NP_inner (NNS securities) (JJ firm))))) (PP (IN with) (NP (ADJP (QP (# #) (QP_inner (CD 500) (CD million))) (-NONE- *U*)) (NN capital)))))))) (, ,)))))) (S_inner (`` ``) (S_inner (VP (VBZ follows) (NP (NP (DT the) (NNS fortunes)) (PP (IN of) (NP (NP (DT a) (NP_inner (JJ close-knit) (NN team))) (PP (IN of) (NP (NP (JJ young) (NP_inner (, ,) (NP_inner (JJ high-flying) (NNS dealers)))) (NP_inner (, ,) (VP (VBN hired) (VP_inner (NP (-NONE- *)) (PP-CLR (IN for) (NP (NP (PRP$ their) (NP_inner (JJ particular) (NN blend))) (PP (IN of) (NP (NP (NN style)) (NP_inner (, ,) (NP_inner (NP (NN genius)) (NP_inner (CC and) (NP (NN energy)))))))))))))))))) (. .))))))
#
# -------------------end of sentence-----------------
#
# But with all the money and glamour of high finance come the relentless pressures to do well ; pressure to pull off another million before lunch ; pressure to anticipate the market by a fraction of a second ... ''
#
# Error: pop on empty buffer
# [ (CC But),  (S (PP (IN with) (NP (DT all) (NP (JJ the) (NN money)))) (S (, (SBAR (CC and) (S (NP (NN glamour) (PP (IN of) (NP (NP (JJ high) (NNS finance)) (SBAR (IN come) (S (NP (DT the) (NP (JJ relentless) (NN pressures))) (VP (TO to) (VP (VBP do) (NNS well)))))))) (VP (NP (PRP ;)) (VP (NP (NN pressure)) (VP (TO to) (VP (VB pull) (VP (PP (IN off) (NP (CD another) (CD million))) (PP (IN before) (NP (NNP lunch))))))))))) (S (: ;) (S (NN pressure) (VP (TO to) (VP (VB anticipate) (VP (NP (DT the) (NN market)) (PP (IN by) (NP (NP (DT a) (NN fraction)) (PP (IN of) (NP (DT a) (JJ second)))))))))))),  (RB ...),  ('' '')]
#
# GROUND TRUTH:
#  (SINV (CC But) (SINV_inner (PP-CLR-TPC-1 (IN with) (NP (NP (PDT all) (NP_inner (DT the) (NP_inner (NN money) (NP_inner (CC and) (NN glamour))))) (PP (IN of) (NP (JJ high) (NN finance))))) (SINV_inner (VP (VBP come) (PP-CLR (-NONE- *T*-1))) (SINV_inner (NP-SBJ (NP (DT the) (NP_inner (JJ relentless) (NP_inner (NNS pressures) (S (NP-SBJ (-NONE- *)) (VP (TO to) (VP (VB do) (ADVP-CLR (RB well)))))))) (NP-SBJ_inner (: ;) (NP-SBJ_inner (NP (NN pressure) (S (NP-SBJ (-NONE- *)) (VP (TO to) (VP (VB pull) (VP_inner (PRT (RP off)) (VP_inner (NP (DT another) (CD million)) (PP-TMP (IN before) (NP (NN lunch))))))))) (NP-SBJ_inner (: ;) (NP (NN pressure) (S (NP-SBJ (-NONE- *)) (VP (TO to) (VP (VB anticipate) (VP_inner (NP (DT the) (NN market)) (PP-CLR (IN by) (NP (NP (DT a) (NN fraction)) (PP (IN of) (NP (DT a) (NN second)))))))))))))) (SINV_inner (: ...) ('' ''))))))
#
# -------------------end of sentence-----------------
#
# You need n't be a high-powered securities lawyer to realize 0 the prospectus is guilty of less than full disclosure .
#
# [ (S (JJ You) (S (VP (VBD need) (VP (RB n't) (VP (VB be) (S (NP (NP (DT a) (NNS high-powered)) (NP (NP (NONE securities)) (S (NP (NN lawyer)) (VP (TO to) (VP (VB realize) (NP (NP (NONE 0)) (NP (DT the) (NN prospectus)))))))) (VP (VBZ is) (NP (NP (NN guilty)) (PP (IN of) (NP (JJ less) (PP (IN than) (NP (JJ full) (NNS disclosure))))))))))) (. .)))]
#
# GROUND TRUTH:
#  (S (NP-SBJ (PRP You)) (S_inner (VP (MD need) (VP_inner (RB n't) (VP (VB be) (VP_inner (NP-PRD (DT a) (NP-PRD_inner (JJ high-powered) (NP-PRD_inner (NNS securities) (NN lawyer)))) (S-PRP (NP-SBJ (-NONE- *)) (VP (TO to) (VP (VB realize) (SBAR (-NONE- 0) (S (NP-SBJ (DT the) (NN prospectus)) (VP (VBZ is) (ADJP-PRD (JJ guilty) (PP (IN of) (NP (NP (RBR less)) (PP (IN than) (NP (JJ full) (NN disclosure)))))))))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# The slickly produced series has been criticized by London 's financial cognoscenti as inaccurate in detail , but its major weakness is its unrealistic depiction of the characters ' professional and private lives .
#
# [ (S (NP (DT The) (NP (JJ slickly) (NP (JJ produced) (NN series)))) (S (S (PP (VP (VBZ has) (VP (VBN been) (VP (NP (NONE criticized)) (VP (PP (IN by) (NP (NP (NNP London) (POS 's)) (NP (JJ financial) (NN cognoscenti)))) (PP (IN as) (NP (NN inaccurate) (PP (IN in) (NP (NNP detail))))))))) (NP (, ,) (NP (NN but) (NP (PRP$ its) (NP (JJ major) (NN weakness)))))) (VP (VBZ is) (NP (NP (NP (PRP$ its) (NP (NN unrealistic) (NN depiction))) (PP (IN of) (NP (NP (NP (DT the) (NNS characters)) (POS ')) (NN professional)))) (NP (CC and) (NP (JJ private) (NN lives)))))) (. .)))]
#
# GROUND TRUTH:
#  (S (S (NP-SBJ-1 (DT The) (NP-SBJ-1_inner (ADJP (RB slickly) (VBD produced)) (NN series))) (VP (VBZ has) (VP (VBN been) (VP (VBN criticized) (VP_inner (NP (-NONE- *-1)) (VP_inner (PP (IN by) (NP-LGS (NP (NNP London) (POS 's)) (NP-LGS_inner (JJ financial) (NNS cognoscenti)))) (PP-CLR (IN as) (ADJP (JJ inaccurate) (PP (IN in) (NP (NN detail))))))))))) (S_inner (, ,) (S_inner (CC but) (S_inner (S (NP-SBJ (PRP$ its) (NP-SBJ_inner (JJ major) (NN weakness))) (VP (VBZ is) (NP-PRD (NP (PRP$ its) (NP_inner (JJ unrealistic) (NN depiction))) (PP (IN of) (NP (NP (DT the) (NP_inner (NNS characters) (POS '))) (NP_inner (ADJP (ADJP (JJ professional)) (ADJP_inner (CC and) (ADJP (JJ private)))) (NNS lives))))))) (. .)))))
#
# -------------------end of sentence-----------------
#
# Turned loose in Shane Longman 's trading room , the yuppie dealers do little right .
#
# Error: binary on insufficient stack
# []
#
# GROUND TRUTH:
#  (S (S-ADV (NP-SBJ (-NONE- *-1)) (VP (VBN Turned) (VP_inner (ADVP-CLR (RB loose)) (PP-CLR (IN in) (NP (NP (NNP Shane) (NP_inner (NNP Longman) (POS 's))) (NP_inner (NN trading) (NN room))))))) (S_inner (, ,) (S_inner (NP-SBJ-1 (DT the) (NP-SBJ-1_inner (NN yuppie) (NNS dealers))) (S_inner (VP (VBP do) (NP (NP (RB little)) (ADJP (RB right)))) (. .)))))
#
# -------------------end of sentence-----------------
#
# Judging by the money lost and mistakes made in the early episodes , Shane Longman 's capital should be just about exhausted by the final 13th week .
#
# Error: binary on insufficient stack
# []
#
# GROUND TRUTH:
#  (S (S-ADV (NP-SBJ (-NONE- *)) (VP (VBG Judging) (PP-CLR (IN by) (NP (NP (NP (NP (DT the) (NN money)) (VP (VBN lost) (NP (-NONE- *)))) (NP_inner (CC and) (NP (NP (NNS mistakes)) (VP (VBN made) (NP (-NONE- *)))))) (PP-LOC (IN in) (NP (DT the) (NP_inner (JJ early) (NNS episodes)))))))) (S_inner (, ,) (S_inner (NP-SBJ (NP (NNP Shane) (NP_inner (NNP Longman) (POS 's))) (NN capital)) (S_inner (VP (MD should) (VP (VB be) (VP_inner (ADJP-PRD (ADVP (RB just) (IN about)) (VBN exhausted)) (PP-TMP (IN by) (NP (DT the) (NP_inner (JJ final) (NP_inner (JJ 13th) (NN week)))))))) (. .)))))
#
# -------------------end of sentence-----------------
#
# In the opening episode we learn that Michelle , a junior bond trader , has indeed pulled off another million before lunch .
#
# Error: pop on empty buffer
# [ (PP (IN In) (NP (NP (DT the) (NP (JJ opening) (NN episode))) (NP (NP (PRP we)) (NP (JJ learn) (NP (IN that) (NNP Michelle)))))),  (, ,),  (NP (NP (DT a) (NP (NN junior) (NP (NN bond) (NN trader)))) (S (, ,) (VP (VBZ has) (NP (NP (NONE indeed)) (NP (DT pulled) (NP (IN off) (NP (NP (DT another) (NNS million)) (PP (IN before) (NP (NNP lunch)))))))))),  (VBD (. .))]
#
# GROUND TRUTH:
#  (S (PP-LOC (IN In) (NP (DT the) (NP_inner (VBG opening) (NN episode)))) (S_inner (NP-SBJ (PRP we)) (S_inner (VP (VBP learn) (SBAR (IN that) (S (NP-SBJ (NP (NNP Michelle)) (NP-SBJ_inner (, ,) (NP-SBJ_inner (NP (DT a) (NP_inner (JJ junior) (NP_inner (NN bond) (NN trader)))) (, ,)))) (VP (VBZ has) (VP_inner (ADVP (RB indeed)) (VP (VBN pulled) (VP_inner (PRT (RP off)) (VP_inner (NP (DT another) (CD million)) (PP-TMP (IN before) (NP (NN lunch))))))))))) (. .))))
#
# -------------------end of sentence-----------------
#
# Trouble is , 0 she has lost it just as quickly .
#
# [ (S (NNP Trouble) (S (S (SBAR (VBZ is) (S (, ,) (NP (NP (NONE 0)) (NP (PRP she))))) (VP (VBP has) (NP (RB lost) (NP (NP (PRP it)) (NP (RB just) (NP (NNP as) (NN quickly))))))) (. .)))]
#
# GROUND TRUTH:
#  (S (NP-SBJ (NN Trouble)) (S_inner (VP (VBZ is) (VP_inner (, ,) (SBAR-PRD (-NONE- 0) (S (NP-SBJ (PRP she)) (VP (VBZ has) (VP (VBN lost) (VP_inner (NP (PRP it)) (ADVP-MNR (RB just) (ADVP-MNR_inner (RB as) (RB quickly)))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# Rather than keep the loss a secret from the outside world , Michelle blabs about it to a sandwich man while ordering lunch over the phone .
#
# [ (S (NNP Rather) (S (VP (IN than) (VP (NNP keep) (VP (NP (DT the) (NN loss)) (VP (NP (DT a) (NN secret)) (VP (PP (IN from) (NP (DT the) (NP (JJ outside) (NN world)))) (VP (, ,) (PP (IN Michelle) (NP (NNP blabs) (SBAR (IN about) (S (NP (PRP it)) (VP (PP (TO to) (NP (DT a) (NP (NN sandwich) (NN man)))) (PP (IN while) (NP (NP (NN ordering) (NNS lunch)) (NP (CC over) (NP (DT the) (NN phone)))))))))))))))) (. .)))]
# GROUND TRUTH:
#  (S (SBAR-ADV (PP (RB Rather)) (SBAR-ADV_inner (IN than) (S (NP-SBJ (-NONE- *-1)) (VP (VB keep) (S (NP-SBJ (DT the) (NN loss)) (NP-PRD (NP (DT a) (NN secret)) (PP (IN from) (NP (DT the) (NP_inner (JJ outside) (NN world)))))))))) (S_inner (, ,) (S_inner (NP-SBJ-1 (NNP Michelle)) (S_inner (VP (VBZ blabs) (VP_inner (PP-CLR (IN about) (NP (PRP it))) (VP_inner (PP-CLR (TO to) (NP (DT a) (NP_inner (NN sandwich) (NN man)))) (SBAR-TMP (IN while) (S-NOM (NP-SBJ (-NONE- *)) (VP (VBG ordering) (VP_inner (NP (NN lunch)) (PP-MNR (IN over) (NP (DT the) (NN phone)))))))))) (. .)))))
#
# -------------------end of sentence-----------------
#
# Little chance that Shane Longman is going to recoup today .
#
# [ (S (NP (NNP Little) (NN chance)) (S (NP (DT that) (NN Shane)) (S (VP (VBP Longman) (VP (VBZ is) (VP (VBG going) (VP (TO to) (VP (VB recoup) (NN today)))))) (. .))))]
#
# GROUND TRUTH:
#  (FRAG (NP (JJ Little) (NP_inner (NN chance) (SBAR (IN that) (S (NP-SBJ-1 (NNP Shane) (NNP Longman)) (VP (VBZ is) (VP (VBG going) (S (NP-SBJ (-NONE- *-1)) (VP (TO to) (VP (VB recoup) (NP-TMP (NN today))))))))))) (. .))
#
# -------------------end of sentence-----------------
#
# Traders spend the morning frantically selling bonds , in the belief that the U.S. monthly trade figures will look lousy .
#
# feature extraction error
# GROUND TRUTH:
#  (S (NP-SBJ (NNS Traders)) (S_inner (VP (VBP spend) (VP_inner (NP-CLR (DT the) (NN morning)) (VP_inner (S (NP-SBJ (-NONE- *)) (VP (ADVP-MNR (RB frantically)) (VP_inner (VBG selling) (NP (NNS bonds))))) (VP_inner (, ,) (PP (IN in) (NP (DT the) (NP_inner (NN belief) (SBAR (IN that) (S (NP-SBJ (DT the) (NP-SBJ_inner (NNP U.S.) (NP-SBJ_inner (JJ monthly) (NP-SBJ_inner (NN trade) (NNS figures))))) (VP (MD will) (VP (VB look) (ADJP-PRD (JJ lousy))))))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# Ah , perfidious Columbia !
#
# Error: pop on empty buffer
# [ (NP (NNP Ah) (NP (, ,) (NP (JJ perfidious) (NN Columbia)))),  (VBD !)]
#
# GROUND TRUTH:
#  (INTJ (UH Ah) (INTJ_inner (, ,) (INTJ_inner (NP (JJ perfidious) (NNP Columbia)) (. !))))
#
# -------------------end of sentence-----------------
#
# The trade figures turn out well , and all those recently unloaded bonds spurt in price .
#
# [ (S (NP (DT The) (NP (NN trade) (NNS figures))) (S (VP (VP (VB turn) (NP (JJ out) (RB well))) (VP (, ,) (NP (CC and) (NP (NP (DT all) (NP (DT those) (NN recently))) (PP (IN unloaded) (NP (NP (NN bonds) (NNS spurt)) (PP (IN in) (NN price)))))))) (. .)))]
#
# GROUND TRUTH:
#  (S (S (NP-SBJ (DT The) (NP-SBJ_inner (NN trade) (NNS figures))) (VP (VBP turn) (VP_inner (PRT (RP out)) (ADVP-CLR (RB well))))) (S_inner (, ,) (S_inner (CC and) (S_inner (S (NP-SBJ (PDT all) (NP-SBJ_inner (DT those) (NP-SBJ_inner (ADJP (RB recently) (VBN unloaded)) (NNS bonds)))) (VP (VBP spurt) (PP (IN in) (NP (NN price))))) (. .)))))
#
# -------------------end of sentence-----------------
#
# So much for anticipating the market by a fraction of a second .
#
# [ (S (RB So) (S (VP (JJ much) (VP (IN for) (VP (NNS anticipating) (VP (NP (DT the) (NN market)) (PP (IN by) (NP (NP (DT a) (NN fraction)) (PP (IN of) (NP (DT a) (NN second))))))))) (. .)))]
#
# GROUND TRUTH:
#  (X (NP-ADV (RB So) (RB much)) (X_inner (PP (IN for) (S-NOM (NP-SBJ (-NONE- *)) (VP (VBG anticipating) (VP_inner (NP (DT the) (NN market)) (PP-CLR (IN by) (NP (NP (DT a) (NN fraction)) (PP (IN of) (NP (DT a) (NN second))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# And a large slice of the first episode is devoted to efforts to get rid of some nearly worthless Japanese bonds -LRB- since when is anything Japanese nearly worthless nowadays ? -RRB- .
#
# [ (S (CC And) (S (NP (NP (DT a) (NP (JJ large) (NN slice))) (PP (IN of) (NP (DT the) (NP (JJ first) (NN episode))))) (S (VP (VBZ is) (S (NP (NN devoted)) (VP (TO to) (VP (VB efforts) (VP (TO to) (VP (VB get) (NP (NP (NNS rid)) (PP (IN of) (NP (NP (DT some) (NP (JJ nearly) (NP (NN worthless) (NP (NN Japanese) (NNS bonds))))) (VP (MD -LRB-) (VP (VB since) (VP (NN when) (VP (VBZ is) (NP (NP (JJ anything) (NP (JJ Japanese) (NN nearly))) (PP (IN worthless) (NP (NP (NN nowadays) (NN ?)) (FW -RRB-))))))))))))))))) (. .))))]
#
# GROUND TRUTH:
#  (S (CC And) (S_inner (NP-SBJ-1 (NP (DT a) (NP_inner (JJ large) (NN slice))) (PP (IN of) (NP (DT the) (NP_inner (JJ first) (NN episode))))) (S_inner (VP (VBZ is) (VP (VBN devoted) (VP_inner (NP (-NONE- *-1)) (VP_inner (PP-CLR (TO to) (NP (NNS efforts) (S (NP-SBJ (-NONE- *)) (VP (TO to) (VP (VB get) (ADJP-PRD (JJ rid) (PP (IN of) (NP (DT some) (NP_inner (ADJP (RB nearly) (JJ worthless)) (NP_inner (JJ Japanese) (NNS bonds))))))))))) (PRN (-LRB- -LRB-) (PRN_inner (SBARQ (WHPP-3 (IN since) (WHADVP (WRB when))) (SQ (VBZ is) (SQ_inner (NP-SBJ (NP (NN anything)) (ADJP (JJ Japanese))) (SQ_inner (ADJP-PRD (RB nearly) (JJ worthless)) (SQ_inner (ADVP-TMP (RB nowadays)) (PP-TMP (-NONE- *T*-3))))))) (PRN_inner (. ?) (-RRB- -RRB-)))))))) (. .))))
#
# -------------------end of sentence-----------------
#
# Surprisingly , Shane Longman survives the week , only to have a senior executive innocently bumble his way into becoming the target of a criminal insider trading investigation .
#
# [ (S (NNP Surprisingly) (S (VP (, ,) (VP (NP (NNP Shane) (NP (NNP Longman) (NP (NNP survives) (NP (DT the) (NN week))))) (VP (, ,) (VP (RB only) (VP (TO to) (VP (VB have) (VP (NP (DT a) (NP (JJ senior) (NN executive))) (VP (NP (NONE innocently)) (VP (VBG bumble) (NP (NP (PRP$ his) (NN way)) (PP (IN into) (VP (VBG becoming) (NP (NP (DT the) (NN target)) (PP (IN of) (NP (DT a) (NP (JJ criminal) (NP (NN insider) (NP (NN trading) (NN investigation))))))))))))))))))) (. .)))]
#
# GROUND TRUTH:
#  (S (ADVP (RB Surprisingly)) (S_inner (, ,) (S_inner (NP-SBJ (NNP Shane) (NNP Longman)) (S_inner (VP (VBZ survives) (VP_inner (NP (DT the) (NN week)) (VP_inner (, ,) (S-ADV (ADVP (RB only)) (S-ADV_inner (NP-SBJ (-NONE- *)) (VP (TO to) (VP (VB have) (S (NP-SBJ (DT a) (NP-SBJ_inner (JJ senior) (NN executive))) (VP (ADVP-MNR (RB innocently)) (VP_inner (VB bumble) (VP_inner (NP (PRP$ his) (NN way)) (PP-DIR (IN into) (S-NOM (NP-SBJ (-NONE- *)) (VP (VBG becoming) (NP-PRD (NP (DT the) (NN target)) (PP (IN of) (NP (DT a) (NP_inner (JJ criminal) (NP_inner (NN insider) (NP_inner (NN trading) (NN investigation))))))))))))))))))))) (. .)))))
#
# -------------------end of sentence-----------------
#
# Instead of closing ranks to protect the firm 's reputation , the executive 's internal rivals , led by a loutish American , demand his resignation .
#
# [ (S (NP (NN Instead) (S (IN of) (S (NP (NN closing) (NN ranks)) (S (TO to) (VP (VBG protect) (NP (NP (DT the) (NP (NN firm) (POS 's))) (NN reputation))))))) (S (, ,) (S (NP (NP (NP (DT the) (NP (NN executive) (POS 's))) (NP (JJ internal) (NN rivals))) (NP (, ,) (NP (NP (NN led) (PP (IN by) (NP (DT a) (NP (NN loutish) (NN American))))) (NP (, ,) (NP (NN demand) (NP (NN his) (NN resignation))))))) (. .))))]
#
# GROUND TRUTH:
#  (S (PP (RB Instead) (PP_inner (IN of) (S-NOM (NP-SBJ (-NONE- *)) (VP (VBG closing) (VP_inner (NP (NNS ranks)) (S-PRP (NP-SBJ (-NONE- *)) (VP (TO to) (VP (VB protect) (NP (NP (DT the) (NP_inner (NN firm) (POS 's))) (NN reputation)))))))))) (S_inner (, ,) (S_inner (NP-SBJ (NP (NP (DT the) (NP_inner (NN executive) (POS 's))) (NP_inner (JJ internal) (NNS rivals))) (NP-SBJ_inner (, ,) (NP-SBJ_inner (VP (VBN led) (VP_inner (NP (-NONE- *)) (PP (IN by) (NP-LGS (DT a) (NP-LGS_inner (JJ loutish) (NNP American)))))) (, ,)))) (S_inner (VP (VBP demand) (NP (PRP$ his) (NN resignation))) (. .)))))
#
# ...
#
# Error: binary on insufficient stack
# []
#
# GROUND TRUTH:
#  (S (S-TPC-1 (NP-SBJ (NP (NNS Stocks)) (PP (JJ such) (PP_inner (IN as) (NP (NP (NNP Hershey) (NP_inner (NNPS Foods) (NNP Corp.))) (NP_inner (, ,) (NP_inner (NP (NNP Wal-Mart) (NP_inner (NNPS Stores) (NNP Inc.))) (NP_inner (, ,) (NP_inner (NP (NNP American) (NP_inner (NNP International) (NP_inner (NNP Group) (NNP Inc.)))) (NP_inner (CC and) (NP (NNP Federal) (NP_inner (NNP National) (NP_inner (NNP Mortgage) (NNP Association))))))))))))) (VP (VBD became) (NP-PRD (NP (JJ such) (NNS bargains)) (SBAR (IN that) (S (NP-SBJ (PRP he)) (VP (MD could) (VP_inner (RB n't) (VP (VB resist) (NP (PRP them)))))))))) (S_inner (, ,) (S_inner (NP-SBJ (PRP he)) (S_inner (VP (VBZ says) (SBAR (-NONE- 0) (S (-NONE- *T*-1)))) (. .)))))
#
# -------------------end of sentence-----------------
#
# And Mr. Craig expects to pick up more shares today .
#
# [ (S (CC And) (S (NP (NNP Mr.) (NNP Craig)) (S (VP (VBZ expects) (VP (TO to) (VP (VB pick) (PP (IN up) (NP (NP (NNP more) (NNS shares)) (NN today)))))) (. .))))]
#
# GROUND TRUTH:
#  (S (CC And) (S_inner (NP-SBJ-1 (NNP Mr.) (NNP Craig)) (S_inner (VP (VBZ expects) (S (NP-SBJ (-NONE- *-1)) (VP (TO to) (VP (VB pick) (VP_inner (PRT (RP up)) (VP_inner (NP (JJR more) (NNS shares)) (NP-TMP (NN today)))))))) (. .))))
#
# -------------------end of sentence-----------------
#
# `` It will be chaotic at first , but I would not be buying if I thought 0 we were headed for real trouble , '' he says .
#
# [ (S (`` ``) (S (S (NP (PRP It)) (VP (MD will) (VP (VB be) (VP (VB chaotic) (PP (IN at) (NP (JJ first))))))) (S (, ,) (S (CC but) (S (S (S (NP (PRP I)) (VP (MD would) (VP (ADVP (RB not)) (VP (VB be) (PP (NP (NONE buying)) (PP (IN if) (NP (PRP I)))))))) (S (VBP thought) (S (NP (NONE 0)) (S (NP (PRP we)) (VP (VBD were) (NP (JJ headed) (PP (IN for) (NP (JJ real) (NN trouble))))))))) (S (, ,) (S ('' '') (S (NP (PRP he)) (S (VBZ says) (. .))))))))))]
#
# GROUND TRUTH:
#  (S (`` ``) (S_inner (S-TPC-2 (S (NP-SBJ (PRP It)) (VP (MD will) (VP (VB be) (VP_inner (ADJP-PRD (JJ chaotic)) (PP-TMP (IN at) (ADVP (JJ first))))))) (S-TPC-2_inner (, ,) (S-TPC-2_inner (CC but) (S (NP-SBJ (PRP I)) (VP (MD would) (VP_inner (RB not) (VP (VB be) (VP (VBG buying) (SBAR-ADV (IN if) (S (NP-SBJ (PRP I)) (VP (VBD thought) (SBAR (-NONE- 0) (S (NP-SBJ-1 (PRP we)) (VP (VBD were) (VP (VBN headed) (VP_inner (NP (-NONE- *-1)) (PP-DIR (IN for) (NP (JJ real) (NN trouble))))))))))))))))))) (S_inner (, ,) (S_inner ('' '') (S_inner (NP-SBJ (PRP he)) (S_inner (VP (VBZ says) (S (-NONE- *T*-2))) (. .)))))))
#
# -------------------end of sentence-----------------
#
# He argues that stocks are reasonably valued now , and that interest rates are lower now than in the fall of 1987 .
#
# Error: pop on empty buffer
# [ (NP (NP (PRP He)) (NP (DT argues) (SBAR (IN that) (S (NP (NNS stocks)) (VP (VBP are) (NP (NP (NONE reasonably)) (NP (JJ valued) (NP (ADVP (RB now)) (NP (, ,) (NP (CC and) (SBAR (IN that) (S (NP (NN interest) (NNS rates)) (VP (VBP are) (VP (VBG lower) (VP (RB now) (VP (IN than) (PP (IN in) (NP (NP (DT the) (NN fall)) (PP (IN of) (ADVP (RB 1987))))))))))))))))))))),  (VBD .)]
#
# GROUND TRUTH:
#  (S (NP-SBJ (PRP He)) (S_inner (VP (VBZ argues) (SBAR (SBAR (IN that) (S (NP-SBJ-1 (NNS stocks)) (S_inner (VP (VBP are) (VP (ADVP-MNR (RB reasonably)) (VP_inner (VBN valued) (NP (-NONE- *-1))))) (ADVP-TMP (RB now))))) (SBAR_inner (, ,) (SBAR_inner (CC and) (SBAR (IN that) (S (NP-SBJ (NN interest) (NNS rates)) (VP (VBP are) (VP_inner (ADJP-PRD (ADJP (JJR lower)) (PP (-NONE- *ICH*-2))) (VP_inner (ADVP-TMP (RB now)) (PP-2 (IN than) (PP-TMP (IN in) (NP (NP (DT the) (NN fall)) (PP (IN of) (NP (CD 1987))))))))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# Mr. Front of Stein Roe suggests that any buying should `` concentrate in stocks that have lagged the market on the up side , or stocks that have been beaten down a lot more than the market in this correction . ''
#
# Error: binary on insufficient stack
# []
#
# GROUND TRUTH:
#  (S (NP-SBJ (NP (NNP Mr.) (NNP Front)) (PP (IN of) (NP (NNP Stein) (NNP Roe)))) (S_inner (VP (VBZ suggests) (SBAR (IN that) (S (NP-SBJ (DT any) (NN buying)) (VP (MD should) (VP_inner (`` ``) (VP (VB concentrate) (PP-LOC-CLR (IN in) (NP (NP (NP (NNS stocks)) (SBAR (WHNP-2 (WDT that)) (S (NP-SBJ (-NONE- *T*-2)) (VP (VBP have) (VP (VBN lagged) (VP_inner (NP (DT the) (NN market)) (PP-LOC (IN on) (NP (DT the) (NP_inner (IN up) (NN side)))))))))) (NP_inner (, ,) (NP_inner (CC or) (NP (NP (NNS stocks)) (SBAR (WHNP-3 (WDT that)) (S (NP-SBJ-1 (-NONE- *T*-3)) (VP (VBP have) (VP (VBN been) (VP (VBN beaten) (VP_inner (NP (-NONE- *-1)) (VP_inner (ADVP-CLR (RB down)) (VP_inner (ADVP-TMP (NP (NP (DT a) (NN lot)) (RBR more)) (PP (IN than) (NP (DT the) (NN market)))) (PP-LOC (IN in) (NP (DT this) (NN correction)))))))))))))))))))))) (S_inner (. .) ('' ''))))
#
# -------------------end of sentence-----------------
#
# His firm favors selected computer , drug and pollution-control stocks .
#
# [ (S (NP (DT His) (NP (NP (NN firm) (NN favors)) (PP (VP selected) (NP (NP (DT computer) (NP (, ,) (NN drug))) (NP (CC and) (NP (JJ pollution-control) (NNS stocks))))))) (. .))]
#
# GROUND TRUTH:
#  (S (NP-SBJ (PRP$ His) (NN firm)) (S_inner (VP (VBZ favors) (NP (VBN selected) (NP_inner (NN computer) (NP_inner (, ,) (NP_inner (NN drug) (NP_inner (CC and) (NP_inner (JJ pollution-control) (NNS stocks)))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# Other investment pros are more pessimistic .
#
# feature extraction error
# GROUND TRUTH:
#  (S (NP-SBJ (JJ Other) (NP-SBJ_inner (NN investment) (NNS pros))) (S_inner (VP (VBP are) (ADJP-PRD (RBR more) (JJ pessimistic))) (. .)))
#
# -------------------end of sentence-----------------
#
# They say 0 investors should sell stocks -- but not necessarily right away .
#
# [ (S (S (NP (PRP They)) (S (VBD say) (S (NP (NP (NONE 0)) (NNS investors)) (VP (X should) (VP (NP (NONE sell)) (IN stocks)))))) (S (VBD --) (S (NP (DT but) (NP (RB not) (NP (JJ necessarily) (NP (NN right) (NNS away))))) (. .))))]
#
# GROUND TRUTH:
#  (S (NP-SBJ (PRP They)) (S_inner (VP (VBP say) (SBAR (-NONE- 0) (S (NP-SBJ (NNS investors)) (VP (MD should) (VP (VB sell) (VP_inner (NP (NNS stocks)) (VP_inner (: --) (VP_inner (CC but) (ADVP-TMP (ADVP (RB not) (RB necessarily)) (ADVP-TMP_inner (RB right) (RB away))))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# Many of them stress that the selling can be orderly , gradual , and done when stock prices are rallying .
#
# [ (S (NP (NP (NN Many)) (PP (IN of) (NP (NNP them)))) (S (VP (VP (VBD stress) (SBAR (IN that) (S (NP (DT the) (NN selling)) (VP (MD can) (VP (VB be) (NP (NNP orderly) (NP (, ,) (NNP gradual)))))))) (VP (, ,) (VP (CC and) (VP (VBP done) (S (NP (NN when) (NP (NN stock) (NNS prices))) (VP (VBP are) (VBG rallying))))))) (. .)))]
#
# GROUND TRUTH:
#  (S (NP-SBJ (NP (JJ Many)) (PP (IN of) (NP (PRP them)))) (S_inner (VP (VBP stress) (SBAR (IN that) (S (NP-SBJ (DT the) (NN selling)) (VP (MD can) (VP (VB be) (ADJP-PRD (ADJP (JJ orderly)) (ADJP-PRD_inner (, ,) (ADJP-PRD_inner (ADJP (JJ gradual)) (ADJP-PRD_inner (, ,) (ADJP-PRD_inner (CC and) (VP (VBN done) (SBAR-TMP (WHADVP-1 (WRB when)) (S (NP-SBJ (NN stock) (NNS prices)) (VP (VBP are) (VP (VBG rallying) (ADVP-TMP (-NONE- *T*-1))))))))))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# On Thursday , William Fleckenstein , a Seattle money manager , used futures contracts in his personal account to place a bet that the broad market averages would decline .
#
# [ (S (PP (IN On) (NP (NNP Thursday) (NP (, ,) (NP (NNP William) (NNP Fleckenstein))))) (S (, ,) (S (NP (DT a) (NP (NNP Seattle) (NP (NN money) (NN manager)))) (S (, ,) (S (NP (NN used) (NP (NNS futures) (NN contracts))) (S (IN in) (S (NP (PRP$ his) (NN personal)) (S (NP (NONE account)) (S (TO to) (S (VB place) (S (NP (DT a) (NN bet)) (S (IN that) (S (NP (DT the) (NP (NN broad) (NP (NN market) (NN averages)))) (S (MD would) (S (VB decline) (. .))))))))))))))))]
#
# GROUND TRUTH:
#  (S (PP-TMP (IN On) (NP (NNP Thursday))) (S_inner (, ,) (S_inner (NP-SBJ (NP (NNP William) (NNP Fleckenstein)) (NP-SBJ_inner (, ,) (NP-SBJ_inner (NP (DT a) (NP_inner (NNP Seattle) (NP_inner (NN money) (NN manager)))) (, ,)))) (S_inner (VP (VBD used) (VP_inner (NP-1 (NP (NNS futures) (NNS contracts)) (PP (IN in) (NP (PRP$ his) (NP_inner (JJ personal) (NN account))))) (S-CLR (NP-SBJ (-NONE- *-1)) (VP (TO to) (VP (VB place) (NP (DT a) (NP_inner (NN bet) (SBAR (IN that) (S (NP-SBJ (DT the) (NP-SBJ_inner (JJ broad) (NP-SBJ_inner (NN market) (NNS averages)))) (VP (MD would) (VP (VB decline)))))))))))) (. .)))))
#
# -------------------end of sentence-----------------
#
# He thinks 0 the underlying inflation rate is around 5 % to 6 % , far higher than most people suppose .
#
# Error: pop on empty buffer
# [ (NP (PRP He)),  (VBD thinks),  (NONE 0),  (NP (DT the) (NP (JJ underlying) (NP (NN inflation) (NN rate)))),  (VBZ is),  (NP (DT around) (NP (CD 5) (NN %))),  (PP (TO to) (NP (CD 6) (NN %))),  (, ,),  (NP (NP (NNP far) (NP (VBD higher) (PP (IN than) (NP (NP (DT most) (NNS people)) (RB suppose))))) (VBD .))]
#
# GROUND TRUTH:
#  (S (NP-SBJ (PRP He)) (S_inner (VP (VBZ thinks) (SBAR (-NONE- 0) (S (NP-SBJ (DT the) (NP-SBJ_inner (VBG underlying) (NP-SBJ_inner (NN inflation) (NN rate)))) (VP (VBZ is) (NP-PRD (NP (QP (IN around) (QP_inner (CD 5) (QP_inner (NN %) (QP_inner (TO to) (QP_inner (CD 6) (NN %)))))) (-NONE- *U*)) (NP-PRD_inner (, ,) (ADJP (ADJP (RB far) (JJR higher)) (SBAR (IN than) (S (NP-SBJ (JJS most) (NNS people)) (VP (VBP suppose))))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# In the pension accounts 0 he manages , Mr. Fleckenstein has raised cash positions and invested in gold and natural gas stocks , partly as an inflation hedge .
#
# feature extraction error
# GROUND TRUTH:
#  (S (PP-LOC (IN In) (NP (NP (DT the) (NP_inner (NN pension) (NNS accounts))) (SBAR (WHNP-1 (-NONE- 0)) (S (NP-SBJ (PRP he)) (VP (VBZ manages) (NP (-NONE- *T*-1))))))) (S_inner (, ,) (S_inner (NP-SBJ (NNP Mr.) (NNP Fleckenstein)) (S_inner (VP (VBZ has) (VP (VP (VBN raised) (NP (NN cash) (NNS positions))) (VP_inner (CC and) (VP (VP (VBN invested) (VP_inner (PP-LOC-CLR (IN in) (NP (NP (NN gold) (NX (-NONE- *RNR*-2))) (NP_inner (CC and) (NP_inner (NP (JJ natural) (NP_inner (NN gas) (NX (-NONE- *RNR*-2)))) (NX-2 (NNS stocks)))))) (VP_inner (, ,) (PP (ADVP (RB partly)) (PP_inner (IN as) (NP (DT an) (NP_inner (NN inflation) (NN hedge)))))))))))) (. .)))))
#
# -------------------end of sentence-----------------
#
# He thinks 0 government officials are terrified to let a recession start when government , corporate and personal debt levels are so high .
#
# [ (S (NP (PRP He)) (S (NP (NP (DT thinks) (NP (NP (NONE 0)) (NN government))) (NNS officials)) (S (VP (VBP are) (S (JJ terrified) (VP (TO to) (VP (VB let) (VP (NP (DT a) (NN recession)) (PP (IN start) (NP (NN when) (NN government)))))))) (S (, ,) (S (NP (VB corporate) (NP (CC and) (NP (NP (JJ personal) (NN debt)) (NNS levels)))) (S (VP (VBP are) (ADJP (RB so) (JJ high))) (. .)))))))]
#
# GROUND TRUTH:
#  (S (NP-SBJ (PRP He)) (S_inner (VP (VBZ thinks) (SBAR (-NONE- 0) (S (NP-SBJ (NN government) (NNS officials)) (VP (VBP are) (ADJP-PRD (VBN terrified) (S (NP-SBJ (-NONE- *)) (VP (TO to) (VP (VB let) (VP_inner (S (NP-SBJ (DT a) (NN recession)) (VP (VB start))) (SBAR-TMP (WHADVP-1 (WRB when)) (S (NP-SBJ (UCP (NN government) (UCP_inner (, ,) (UCP_inner (JJ corporate) (UCP_inner (CC and) (JJ personal))))) (NP-SBJ_inner (NN debt) (NNS levels))) (VP (VBP are) (VP_inner (ADJP-PRD (RB so) (JJ high)) (ADVP-TMP (-NONE- *T*-1))))))))))))))) (. .)))
#
# -------------------end of sentence-----------------
#
# So he thinks 0 the government will err on the side of rekindled inflation .
#
# [ (S (NP (NNP So) (NP (NP (PRP he)) (NP (RB thinks) (NP (NP (NONE 0)) (NP (NP (NP (DT the) (NN government)) (NP (NP (NONE will)) (NN err))) (PP (IN on) (NP (NP (DT the) (NN side)) (PP (IN of) (NP (JJ rekindled) (NN inflation)))))))))) (. .))]
#
# GROUND TRUTH:
#  (S (ADVP (IN So)) (S_inner (NP-SBJ (PRP he)) (S_inner (VP (VBZ thinks) (SBAR (-NONE- 0) (S (NP-SBJ (DT the) (NN government)) (VP (MD will) (VP (VB err) (PP-LOC-CLR (IN on) (NP (NP (DT the) (NN side)) (PP (IN of) (NP (VBN rekindled) (NN inflation)))))))))) (. .))))
#
# -------------------end of sentence-----------------
#
# As a result , Mr. Fleckenstein says 0 , `` I think 0 the ball game 's over , '' and investors are about to face a bear market .
#
# [ (S (PP (IN As) (NP (DT a) (NN result))) (S (, ,) (S (NP (NNP Mr.) (NNP Fleckenstein)) (S (VP (VBZ says) (VP (NP (NONE 0)) (VP (, ,) (SBAR (`` ``) (S (NP (PRP I)) (VP (VBP think) (SBAR (NONE 0) (S (NP (NP (DT the) (NP (NN ball) (NP (NN game) (POS 's)))) (NN over)) (VP (, ,) (VP (NP (NP (JJ '') (NN and)) (NNS investors)) (VP (VBP are) (VP (IN about) (VP (TO to) (VP (VB face) (NP (DT a) (NP (NN bear) (NN market))))))))))))))))) (. .)))))]
#
# GROUND TRUTH:
#  (S-1 (PP (IN As) (NP (DT a) (NN result))) (S-1_inner (PRN (, ,) (PRN_inner (S (NP-SBJ (NNP Mr.) (NNP Fleckenstein)) (VP (VBZ says) (SBAR (-NONE- 0) (S (-NONE- *T*-1))))) (, ,))) (S-1_inner (`` ``) (S-1_inner (S (NP-SBJ (PRP I)) (VP (VBP think) (SBAR (-NONE- 0) (S (NP-SBJ (DT the) (NP-SBJ_inner (NN ball) (NN game))) (VP (VBZ 's) (ADJP-PRD (IN over))))))) (S-1_inner (, ,) (S-1_inner ('' '') (S-1_inner (CC and) (S-1_inner (S (NP-SBJ-2 (NNS investors)) (VP (VBP are) (VP (IN about) (S (NP-SBJ (-NONE- *-2)) (VP (TO to) (VP (VB face) (NP (DT a) (NP_inner (NN bear) (NN market))))))))) (. .)))))))))
#
# -------------------end of sentence-----------------
#
# David M. Jones , vice president at Aubrey G. Lanston & Co. , recommends Treasury securities -LRB- of up to five years ' maturity -RRB- .
# Error: pop on empty buffer
# [ (NP (NNP David) (NP (NNP M.) (NNP Jones))),  (, ,),  (NP (NP (NP (NN vice) (NN president)) (PP (IN at) (NP (NNP Aubrey) (NP (NNP G.) (NP (NNP Lanston) (NP (CC &) (NNP Co.))))))) (NP (, ,) (NP (NP (NNP recommends) (NP (NNP Treasury) (NNP securities))) (NP (, -LRB-) (SBAR (IN of) (S (NP (NN up)) (PP (TO to) (NP (NP (CD five) (NP (NNS years) (POS '))) (NP (JJ maturity) (NN -RRB-)))))))))),  (VBD .)]
#
# GROUND TRUTH:
#  (S (NP-SBJ (NP (NNP David) (NP_inner (NNP M.) (NNP Jones))) (NP-SBJ_inner (, ,) (NP-SBJ_inner (NP (NP (NN vice) (NN president)) (PP-LOC (IN at) (NP (NNP Aubrey) (NP_inner (NNP G.) (NP_inner (NNP Lanston) (NP_inner (CC &) (NNP Co.))))))) (, ,)))) (S_inner (VP (VBZ recommends) (NP (NP (NN Treasury) (NNS securities)) (PRN (-LRB- -LRB-) (PRN_inner (PP (IN of) (NP (NP (QP (IN up) (QP_inner (TO to) (CD five))) (NP_inner (NNS years) (POS '))) (NN maturity))) (-RRB- -RRB-))))) (. .)))
#
# -------------------end of sentence-----------------
#
# He says 0 the Oct. 6 employment report , showing slower economic growth and a severe weakening in the manufacturing sector , is a warning sign to investors .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-e654db65096b> in <module>()
#      98
#      99
# --> 100                 pred = network.decode(rearrange([0] + f)[:-1])
#     101                 # outfile.write(str(f) + ' ' +  pred + '\n')
#     102
#
# <ipython-input-2-609703fa08d1> in decode(self, features)
#     136
#     137         # getting best tag
# --> 138         best_tag_id = np.argmax(scores)
#     139
#     140         # assigning the best tag
#
# ~/.virtualenvs/test_py3/lib/python3.4/site-packages/numpy/core/fromnumeric.py in argmax(a, axis, out)
#    1035
#    1036     """
# -> 1037     return _wrapfunc(a, 'argmax', axis=axis, out=out)
#    1038
#    1039
#
# ~/.virtualenvs/test_py3/lib/python3.4/site-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      49 def _wrapfunc(obj, method, *args, **kwds):
#      50     try:
# ---> 51         return getattr(obj, method)(*args, **kwds)
#      52
#      53     # An AttributeError occurs if the object does not have
#
# KeyboardInterrupt:
